# %% [markdown]
# This note book is based entirely on a Kaggle jupyter notebook. https://www.kaggle.com/guoday/two-sigma-connect-rental-listing-inquiries/cv-statistics-edited-0-5346-score/notebook

# %%
import os
import sys
import operator
import numpy as np
import pandas as pd
from scipy import sparse
import xgboost as xgb
import random
from sklearn import model_selection, preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
#input data
train_df=pd.read_json('C:\\Users\\sevda\\Documents\\Data Lab\\Six sigma rental property\\train.json\\train.json')
test_df=pd.read_json('C:\\Users\\sevda\\Documents\\Data Lab\\Six sigma rental property\\test.json\\test.json')

# %% [markdown]
# We will define the XGBoost function

# %%
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=1000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20)
    else:
        xgtest = xgb.DMatrix(test_X)
        print("Before train function")
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %% [markdown]
# We will also define a train_model function which splits the train data set into a training and testing data set, then apply the model XGBoost model and returns the best cross validation scores we can get with the model based on the selected variables which are included in the train_X_full dataset

# %%
#train_y is the column values we want to predict and train_X_full is the dataset with which we want to work 
def train_model(train_X_full, train_y):


        target_num_map = {'high':0, 'medium':1, 'low':2}
        train_y = np.array(train_y.apply(lambda x: target_num_map[x]))

        cv_scores = []
        kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
        i = 0
        for dev_index, val_index in kf.split(range(train_X_full.shape[0])):
            i = i + 1
            #print(train_X_full.loc(dev_index))
            dev_X, val_X = train_X_full.loc[dev_index], train_X_full.loc[val_index]
            dev_y, val_y = train_y[dev_index], train_y[val_index]
            preds, model = runXGB(dev_X, dev_y, val_X, val_y)
            #print(log_loss(val_y, preds))
            cv_scores.append(log_loss(val_y, preds))
            #print(cv_scores)
            break
        return cv_scores

# %% [markdown]
# As part of the feature engineering, we create some basic additional features based on the initial variables.

# %%
#basic features
train_df["price_t"] =train_df["price"]/(train_df["bedrooms"] + 1)
test_df["price_t"] = test_df["price"]/(test_df["bedrooms"] + 1) 
train_df["room_sum"] = train_df["bedrooms"]+train_df["bathrooms"] 
test_df["room_sum"] = test_df["bedrooms"]+test_df["bathrooms"] 

# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))


features_to_use=["bathrooms", "bedrooms", "latitude", "longitude", "price","price_t","num_photos", "num_features", "num_description_words","listing_id"]

# %% [markdown]
# We will create three levels of manager id valuation based on the number of low, medium and high interest for listing interest.

# %%
index=list(range(train_df.shape[0]))
random.shuffle(index)
a=[0]*len(train_df)
b=[0]*len(train_df)
c=[0]*len(train_df)

for i in range(5):
    building_level={}
    for j in train_df['manager_id'].values:
        building_level[j]=[0,0,0]
    test_index=index[int((i*train_df.shape[0])/5):int(((i+1)*train_df.shape[0])/5)]
    train_index=list(set(index).difference(test_index))
    for j in train_index:
        temp=train_df.iloc[j]
        if temp['interest_level']=='low':
            building_level[temp['manager_id']][0]+=1
        if temp['interest_level']=='medium':
            building_level[temp['manager_id']][1]+=1
        if temp['interest_level']=='high':
            building_level[temp['manager_id']][2]+=1
    for j in test_index:
        temp=train_df.iloc[j]
        if sum(building_level[temp['manager_id']])!=0:
            a[j]=building_level[temp['manager_id']][0]*1.0/sum(building_level[temp['manager_id']])
            b[j]=building_level[temp['manager_id']][1]*1.0/sum(building_level[temp['manager_id']])
            c[j]=building_level[temp['manager_id']][2]*1.0/sum(building_level[temp['manager_id']])
train_df['manager_level_low']=a
train_df['manager_level_medium']=b
train_df['manager_level_high']=c



a=[]
b=[]
c=[]
building_level={}
for j in train_df['manager_id'].values:
    building_level[j]=[0,0,0]
for j in range(train_df.shape[0]):
    temp=train_df.iloc[j]
    if temp['interest_level']=='low':
        building_level[temp['manager_id']][0]+=1
    if temp['interest_level']=='medium':
        building_level[temp['manager_id']][1]+=1
    if temp['interest_level']=='high':
        building_level[temp['manager_id']][2]+=1

for i in test_df['manager_id'].values:
    if i not in building_level.keys():
        a.append(0)
        b.append(0)
        c.append(0)
    else:
        a.append(building_level[i][0]*1.0/sum(building_level[i]))
        b.append(building_level[i][1]*1.0/sum(building_level[i]))
        c.append(building_level[i][2]*1.0/sum(building_level[i]))
test_df['manager_level_low']=a
test_df['manager_level_medium']=b
test_df['manager_level_high']=c

#features_to_use.append('manager_level_low') 
#features_to_use.append('manager_level_medium') 
#features_to_use.append('manager_level_high')

# %% [markdown]
# Label encoding transformation of the categorical variables.

# %%
#categorical = ["display_address", "manager_id", "building_id", "street_address"]
categorical = ["manager_id", "building_id"]
for f in categorical:
        if train_df[f].dtype=='object':
            #print(f)
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

# %% [markdown]
# Introducing the price diff variable

# %%
train_group_by = train_df[["bedrooms", "price"]].groupby(["bedrooms"]).median()
train_group_by = train_group_by.add_suffix('_median').reset_index()

train_df = train_df.merge(train_group_by, left_on=['bedrooms'], right_on=['bedrooms'], how='outer')
test_df = test_df.merge(train_group_by, left_on=['bedrooms'], right_on=['bedrooms'], how='left')

train_df["price_diff"] = train_df["price"] - train_df["price_median"]
test_df["price_diff"] = test_df["price"] - test_df["price_median"]

# %% [markdown]
# We will use the created date and will add the day of year, week of year and a number of other data related variables.

# %%
train_df["created"] = pd.to_datetime(train_df["created"])
train_df["date"]= train_df["created"].dt.date

train_df["dayofyear"] = train_df["created"].dt.dayofyear
train_df["weekofyear"] = train_df["created"].dt.weekofyear
train_df["weekday"] = train_df["created"].dt.weekday
train_df["hour"] = train_df["created"].dt.hour

test_df["created"] = pd.to_datetime(test_df["created"])
test_df["date"]= test_df["created"].dt.date

test_df["dayofyear"] = test_df["created"].dt.dayofyear
test_df["weekofyear"] = test_df["created"].dt.weekofyear
test_df["weekday"] = test_df["created"].dt.weekday
test_df["hour"] = test_df["created"].dt.hour

# %% [markdown]
# Adding the count of apartments available for rent in each building.

# %%
building_id_group_by = train_df[["street_address", "building_id"]].groupby(["building_id"]).count()
building_id_group_by = building_id_group_by.add_suffix('_count').reset_index()

train_df = train_df.merge(building_id_group_by, left_on=['building_id'], right_on=['building_id'], how='inner')
test_df = test_df.merge(building_id_group_by, left_on=['building_id'], right_on=['building_id'], how='left')

# %% [markdown]
# Adding a density description variable for the location of the apartments.

# %%
train_df["pos"] = train_df.longitude.round(3).astype(str) + '_' + train_df.latitude.round(3).astype(str)
test_df["pos"] = test_df.longitude.round(3).astype(str) + '_' + test_df.latitude.round(3).astype(str)

vals = train_df['pos'].value_counts()
dvals = vals.to_dict()
train_df["density"] = train_df['pos'].apply(lambda x: dvals.get(x, vals.min()))
test_df["density"] = test_df['pos'].apply(lambda x: dvals.get(x, vals.min()))

# %% [markdown]
# Assessing the manager skill based on the postings with high and low interest.

# %%
train_df['manager_skill'] = train_df['manager_level_high']*3 + train_df['manager_level_medium']*2 + train_df['manager_level_low']
test_df['manager_skill'] = test_df['manager_level_high']*3 + test_df['manager_level_medium']*2 + test_df['manager_level_low']

# %% [markdown]
# Adding a listing difference variable which is a reflection of the position under which a listing appears.

# %%
dayofyear_group_by = train_df[["listing_id", "dayofyear"]].groupby(["dayofyear"]).min()
dayofyear_group_by = dayofyear_group_by.add_suffix('_min').reset_index()

train_df = train_df.merge(dayofyear_group_by, left_on=['dayofyear'], right_on=['dayofyear'], how='left')
train_df['listing_difference'] = train_df['listing_id'] - train_df['listing_id_min']

test_df = test_df.merge(dayofyear_group_by, left_on=['dayofyear'], right_on=['dayofyear'], how='left')
test_df['listing_difference'] = test_df['listing_id'] - test_df['listing_id_min']

# %% [markdown]
# Performing clustering based on the latitude and longitude information in order to form rental unit clusters based on proximity. The idea for teh clustering and part of the code was taken from https://www.kaggle.com/luisblanche/two-sigma-connect-rental-listing-inquiries/price-compared-to-neighborhood-median .

# %%
features_to_use=["bathrooms", "bedrooms", "latitude", "longitude", "listing_difference", "price","price_t","num_photos", "num_features", "num_description_words","listing_id"]

features_to_use.append("price_diff")
features_to_use.append("dayofyear")
features_to_use.append("weekofyear")
features_to_use.append("weekday")
features_to_use.append("hour")
#features_to_use.append("price_diff")
#features_to_use.append("longitude")
#features_to_use.append("latitude")
features_to_use.append("street_address_count")
features_to_use.append("manager_level_low")
features_to_use.append("manager_level_medium")
features_to_use.append("manager_level_high")
#features_to_use.append("pos")
features_to_use.append("density")
features_to_use.append("manager_skill")
#features_to_use.append("listing_difference")

# %%
from sklearn.cluster import Birch
import matplotlib.pyplot as plt

def cluster_latlon(n_clusters, train_df, test_df):  
    train_df['type_df'] = "train"
    test_df['type_df'] = "test"
    
    data = pd.concat([train_df, test_df])
    #split the data between "around NYC" and "other locations" basically our first two clusters 
    data_c=data[(data.longitude>-74.05)&(data.longitude<-73.75)&(data.latitude>40.4)&(data.latitude<40.9)]
    data_e=data[~(data.longitude>-74.05)&(data.longitude<-73.75)&(data.latitude>40.4)&(data.latitude<40.9)]
    #put it in matrix form
    coords=data_c.as_matrix(columns=['latitude', "longitude"])
    
    brc = Birch(branching_factor=100, n_clusters=n_clusters, threshold=0.01,compute_labels=True)

    brc.fit(coords)
    clusters=brc.predict(coords)
    data_c["cluster_"+str(n_clusters)]=clusters
    data_e["cluster_"+str(n_clusters)]=-1 #assign cluster label -1 for the non NYC listings 
    data=pd.concat([data_c,data_e])
    
    res_train_df = data[(data.type_df == "train")]
    res_test_df = data[(data.type_df == "test")]
    
    #Visualizing the clusters
    plt.scatter(data_c["longitude"], data_c["latitude"], c=data_c["cluster_"+str(n_clusters)], s=10, linewidth=0.1)
    plt.title(str(n_clusters)+" Neighbourhoods from clustering")
    plt.show()
    return res_train_df, res_test_df

# %% [markdown]
# Performing clustering with 30 clusters and presenting the results on a map. Other number of clusters have been tried in the model but their overall log loss scores on the test set are pretty close. For that reason an arbitrary number of 30 clusters is selected. We are aiming for a reasonable number of clusters, where the clusters are forming nice and clean regions on the map and at the same time each cluster has plenty of data which will help us with forming the median price value.

# %%
train_X_full, test_X_full = cluster_latlon(30, train_df, test_df)

train_df["cluster_30"] = train_X_full["cluster_30"]
test_df["cluster_30"] = test_X_full["cluster_30"]

features_to_use.append("cluster_30")

train_X_sel = train_X_full[features_to_use]
test_X_sel = test_X_full[features_to_use]

train_model(train_X_sel, train_df['interest_level'])
# Out:
# C:\Users\sevda\Anaconda3\lib\site-packages\ipykernel\__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\sevda\Anaconda3\lib\site-packages\ipykernel\__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# [0]	train-mlogloss:1.03126	test-mlogloss:1.03371
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:0.975082	test-mlogloss:0.97969
# [2]	train-mlogloss:0.928124	test-mlogloss:0.934595
# [3]	train-mlogloss:0.885625	test-mlogloss:0.893553
# [4]	train-mlogloss:0.849103	test-mlogloss:0.859025
# [5]	train-mlogloss:0.817074	test-mlogloss:0.8285
# [6]	train-mlogloss:0.789548	test-mlogloss:0.802038
# [7]	train-mlogloss:0.765422	test-mlogloss:0.779279
# [8]	train-mlogloss:0.743594	test-mlogloss:0.758626
# [9]	train-mlogloss:0.724592	test-mlogloss:0.741018
# [10]	train-mlogloss:0.707958	test-mlogloss:0.725274
# [11]	train-mlogloss:0.69231	test-mlogloss:0.710772
# [12]	train-mlogloss:0.678216	test-mlogloss:0.697641
# [13]	train-mlogloss:0.665793	test-mlogloss:0.686271
# [14]	train-mlogloss:0.654195	test-mlogloss:0.675761
# [15]	train-mlogloss:0.644422	test-mlogloss:0.666862
# [16]	train-mlogloss:0.635246	test-mlogloss:0.658647
# [17]	train-mlogloss:0.627088	test-mlogloss:0.651561
# [18]	train-mlogloss:0.61981	test-mlogloss:0.645176
# [19]	train-mlogloss:0.612648	test-mlogloss:0.639077
# [20]	train-mlogloss:0.606392	test-mlogloss:0.633608
# [21]	train-mlogloss:0.600869	test-mlogloss:0.628861
# [22]	train-mlogloss:0.595469	test-mlogloss:0.624385
# [23]	train-mlogloss:0.590414	test-mlogloss:0.619918
# [24]	train-mlogloss:0.585649	test-mlogloss:0.615881
# [25]	train-mlogloss:0.581539	test-mlogloss:0.612534
# [26]	train-mlogloss:0.577499	test-mlogloss:0.609337
# [27]	train-mlogloss:0.573712	test-mlogloss:0.60648
# [28]	train-mlogloss:0.57026	test-mlogloss:0.603648
# [29]	train-mlogloss:0.56724	test-mlogloss:0.601549
# [30]	train-mlogloss:0.563969	test-mlogloss:0.599029
# [31]	train-mlogloss:0.56086	test-mlogloss:0.596616
# [32]	train-mlogloss:0.558227	test-mlogloss:0.594471
# [33]	train-mlogloss:0.555802	test-mlogloss:0.592853
# [34]	train-mlogloss:0.553553	test-mlogloss:0.591071
# [35]	train-mlogloss:0.551106	test-mlogloss:0.589339
# [36]	train-mlogloss:0.548875	test-mlogloss:0.587899
# [37]	train-mlogloss:0.547183	test-mlogloss:0.586726
# [38]	train-mlogloss:0.545216	test-mlogloss:0.585466
# [39]	train-mlogloss:0.543055	test-mlogloss:0.584102
# [40]	train-mlogloss:0.540704	test-mlogloss:0.58257
# [41]	train-mlogloss:0.53889	test-mlogloss:0.581456
# [42]	train-mlogloss:0.537279	test-mlogloss:0.580425
# [43]	train-mlogloss:0.53569	test-mlogloss:0.579507
# [44]	train-mlogloss:0.534111	test-mlogloss:0.578445
# [45]	train-mlogloss:0.532474	test-mlogloss:0.577486
# [46]	train-mlogloss:0.530564	test-mlogloss:0.576532
# [47]	train-mlogloss:0.528954	test-mlogloss:0.575545
# [48]	train-mlogloss:0.527628	test-mlogloss:0.574889
# [49]	train-mlogloss:0.526226	test-mlogloss:0.574158
# [50]	train-mlogloss:0.524915	test-mlogloss:0.573434
# [51]	train-mlogloss:0.523357	test-mlogloss:0.572636
# [52]	train-mlogloss:0.522113	test-mlogloss:0.571983
# [53]	train-mlogloss:0.520677	test-mlogloss:0.571298
# [54]	train-mlogloss:0.519194	test-mlogloss:0.570794
# [55]	train-mlogloss:0.517651	test-mlogloss:0.570147
# [56]	train-mlogloss:0.516303	test-mlogloss:0.569401
# [57]	train-mlogloss:0.514828	test-mlogloss:0.568802
# [58]	train-mlogloss:0.513552	test-mlogloss:0.568229
# [59]	train-mlogloss:0.512343	test-mlogloss:0.567814
# [60]	train-mlogloss:0.51159	test-mlogloss:0.567374
# [61]	train-mlogloss:0.510406	test-mlogloss:0.566998
# [62]	train-mlogloss:0.50896	test-mlogloss:0.566174
# [63]	train-mlogloss:0.507708	test-mlogloss:0.565562
# [64]	train-mlogloss:0.506815	test-mlogloss:0.565264
# [65]	train-mlogloss:0.505663	test-mlogloss:0.564799
# [66]	train-mlogloss:0.504564	test-mlogloss:0.564495
# [67]	train-mlogloss:0.503277	test-mlogloss:0.564013
# [68]	train-mlogloss:0.502126	test-mlogloss:0.563633
# [69]	train-mlogloss:0.501346	test-mlogloss:0.56324
# [70]	train-mlogloss:0.500008	test-mlogloss:0.56272
# [71]	train-mlogloss:0.498967	test-mlogloss:0.562422
# [72]	train-mlogloss:0.498049	test-mlogloss:0.562129
# [73]	train-mlogloss:0.496556	test-mlogloss:0.561683
# [74]	train-mlogloss:0.495638	test-mlogloss:0.561303
# [75]	train-mlogloss:0.494502	test-mlogloss:0.560864
# [76]	train-mlogloss:0.493519	test-mlogloss:0.560508
# [77]	train-mlogloss:0.492215	test-mlogloss:0.560072
# [78]	train-mlogloss:0.49111	test-mlogloss:0.559723
# [79]	train-mlogloss:0.49033	test-mlogloss:0.559558
# [80]	train-mlogloss:0.489656	test-mlogloss:0.559346
# [81]	train-mlogloss:0.488688	test-mlogloss:0.558905
# [82]	train-mlogloss:0.487719	test-mlogloss:0.558553
# [83]	train-mlogloss:0.48651	test-mlogloss:0.558169
# [84]	train-mlogloss:0.485575	test-mlogloss:0.557821
# [85]	train-mlogloss:0.484903	test-mlogloss:0.557715
# [86]	train-mlogloss:0.484037	test-mlogloss:0.557467
# [87]	train-mlogloss:0.48319	test-mlogloss:0.557176
# [88]	train-mlogloss:0.482177	test-mlogloss:0.557021
# [89]	train-mlogloss:0.481239	test-mlogloss:0.556544
# [90]	train-mlogloss:0.480199	test-mlogloss:0.556298
# [91]	train-mlogloss:0.479206	test-mlogloss:0.555905
# [92]	train-mlogloss:0.478142	test-mlogloss:0.55572
# [93]	train-mlogloss:0.477502	test-mlogloss:0.55561
# [94]	train-mlogloss:0.476765	test-mlogloss:0.555515
# [95]	train-mlogloss:0.475936	test-mlogloss:0.55533
# [96]	train-mlogloss:0.47522	test-mlogloss:0.555352
# [97]	train-mlogloss:0.474471	test-mlogloss:0.555235
# [98]	train-mlogloss:0.473571	test-mlogloss:0.554741
# [99]	train-mlogloss:0.472736	test-mlogloss:0.554767
# [100]	train-mlogloss:0.47213	test-mlogloss:0.554616
# [101]	train-mlogloss:0.471267	test-mlogloss:0.554291
# [102]	train-mlogloss:0.470539	test-mlogloss:0.554113
# [103]	train-mlogloss:0.469775	test-mlogloss:0.553906
# [104]	train-mlogloss:0.469138	test-mlogloss:0.553797
# [105]	train-mlogloss:0.468368	test-mlogloss:0.553525
# [106]	train-mlogloss:0.467488	test-mlogloss:0.553224
# [107]	train-mlogloss:0.466489	test-mlogloss:0.552985
# [108]	train-mlogloss:0.465555	test-mlogloss:0.552873
# [109]	train-mlogloss:0.464563	test-mlogloss:0.552448
# [110]	train-mlogloss:0.463903	test-mlogloss:0.552295
# [111]	train-mlogloss:0.463096	test-mlogloss:0.552114
# [112]	train-mlogloss:0.462373	test-mlogloss:0.551907
# [113]	train-mlogloss:0.461632	test-mlogloss:0.551674
# [114]	train-mlogloss:0.4611	test-mlogloss:0.551611
# [115]	train-mlogloss:0.460267	test-mlogloss:0.551462
# [116]	train-mlogloss:0.459478	test-mlogloss:0.551379
# [117]	train-mlogloss:0.458747	test-mlogloss:0.5513
# [118]	train-mlogloss:0.457881	test-mlogloss:0.551187
# [119]	train-mlogloss:0.457299	test-mlogloss:0.551037
# [120]	train-mlogloss:0.456547	test-mlogloss:0.550849
# [121]	train-mlogloss:0.455699	test-mlogloss:0.550868
# [122]	train-mlogloss:0.455058	test-mlogloss:0.55077
# [123]	train-mlogloss:0.454472	test-mlogloss:0.550735
# [124]	train-mlogloss:0.453975	test-mlogloss:0.550644
# [125]	train-mlogloss:0.453058	test-mlogloss:0.550512
# [126]	train-mlogloss:0.452136	test-mlogloss:0.550416
# [127]	train-mlogloss:0.4516	test-mlogloss:0.550399
# [128]	train-mlogloss:0.45091	test-mlogloss:0.550308
# [129]	train-mlogloss:0.450292	test-mlogloss:0.550304
# [130]	train-mlogloss:0.449702	test-mlogloss:0.550278
# [131]	train-mlogloss:0.448997	test-mlogloss:0.550245
# [132]	train-mlogloss:0.448209	test-mlogloss:0.550051
# [133]	train-mlogloss:0.447761	test-mlogloss:0.550017
# [134]	train-mlogloss:0.447006	test-mlogloss:0.549709
# [135]	train-mlogloss:0.446285	test-mlogloss:0.549626
# [136]	train-mlogloss:0.445568	test-mlogloss:0.549523
# [137]	train-mlogloss:0.444871	test-mlogloss:0.549403
# [138]	train-mlogloss:0.444254	test-mlogloss:0.54939
# [139]	train-mlogloss:0.443461	test-mlogloss:0.549308
# [140]	train-mlogloss:0.442802	test-mlogloss:0.549294
# [141]	train-mlogloss:0.442146	test-mlogloss:0.54922
# [142]	train-mlogloss:0.441466	test-mlogloss:0.54905
# [143]	train-mlogloss:0.440897	test-mlogloss:0.549013
# [144]	train-mlogloss:0.440116	test-mlogloss:0.54863
# [145]	train-mlogloss:0.439333	test-mlogloss:0.548558
# [146]	train-mlogloss:0.438634	test-mlogloss:0.548397
# [147]	train-mlogloss:0.438053	test-mlogloss:0.54831
# [148]	train-mlogloss:0.437238	test-mlogloss:0.548339
# [149]	train-mlogloss:0.436856	test-mlogloss:0.548342
# [150]	train-mlogloss:0.436185	test-mlogloss:0.548231
# [151]	train-mlogloss:0.435604	test-mlogloss:0.548246
# [152]	train-mlogloss:0.434998	test-mlogloss:0.548115
# [153]	train-mlogloss:0.434552	test-mlogloss:0.548022
# [154]	train-mlogloss:0.433935	test-mlogloss:0.54799
# [155]	train-mlogloss:0.43335	test-mlogloss:0.547905
# [156]	train-mlogloss:0.432737	test-mlogloss:0.547962
# [157]	train-mlogloss:0.432149	test-mlogloss:0.547946
# [158]	train-mlogloss:0.431609	test-mlogloss:0.54785
# [159]	train-mlogloss:0.430853	test-mlogloss:0.547636
# [160]	train-mlogloss:0.430161	test-mlogloss:0.547536
# [161]	train-mlogloss:0.429504	test-mlogloss:0.547591
# [162]	train-mlogloss:0.42892	test-mlogloss:0.547566
# [163]	train-mlogloss:0.428409	test-mlogloss:0.547572
# [164]	train-mlogloss:0.427784	test-mlogloss:0.547546
# [165]	train-mlogloss:0.426988	test-mlogloss:0.547581
# [166]	train-mlogloss:0.426395	test-mlogloss:0.547525
# [167]	train-mlogloss:0.425646	test-mlogloss:0.547333
# [168]	train-mlogloss:0.425083	test-mlogloss:0.547294
# [169]	train-mlogloss:0.424381	test-mlogloss:0.547321
# [170]	train-mlogloss:0.423822	test-mlogloss:0.547304
# [171]	train-mlogloss:0.423204	test-mlogloss:0.547299
# [172]	train-mlogloss:0.422746	test-mlogloss:0.547336
# [173]	train-mlogloss:0.422234	test-mlogloss:0.54726
# [174]	train-mlogloss:0.42158	test-mlogloss:0.547181
# [175]	train-mlogloss:0.420947	test-mlogloss:0.546971
# [176]	train-mlogloss:0.420423	test-mlogloss:0.546945
# [177]	train-mlogloss:0.419877	test-mlogloss:0.546918
# [178]	train-mlogloss:0.419195	test-mlogloss:0.546939
# [179]	train-mlogloss:0.418564	test-mlogloss:0.546944
# [180]	train-mlogloss:0.417975	test-mlogloss:0.546757
# [181]	train-mlogloss:0.417073	test-mlogloss:0.546664
# [182]	train-mlogloss:0.416478	test-mlogloss:0.546621
# [183]	train-mlogloss:0.416038	test-mlogloss:0.546539
# [184]	train-mlogloss:0.415527	test-mlogloss:0.546496
# [185]	train-mlogloss:0.41496	test-mlogloss:0.546424
# [186]	train-mlogloss:0.414434	test-mlogloss:0.546345
# [187]	train-mlogloss:0.413857	test-mlogloss:0.546428
# [188]	train-mlogloss:0.413302	test-mlogloss:0.546426
# [189]	train-mlogloss:0.41302	test-mlogloss:0.546487
# [190]	train-mlogloss:0.412355	test-mlogloss:0.546554
# [191]	train-mlogloss:0.411743	test-mlogloss:0.546429
# [192]	train-mlogloss:0.411128	test-mlogloss:0.546451
# [193]	train-mlogloss:0.410429	test-mlogloss:0.546378
# [194]	train-mlogloss:0.409724	test-mlogloss:0.546277
# [195]	train-mlogloss:0.409379	test-mlogloss:0.546229
# [196]	train-mlogloss:0.408863	test-mlogloss:0.546139
# [197]	train-mlogloss:0.408264	test-mlogloss:0.546086
# [198]	train-mlogloss:0.407614	test-mlogloss:0.54603
# [199]	train-mlogloss:0.407091	test-mlogloss:0.545925
# [200]	train-mlogloss:0.406446	test-mlogloss:0.545984
# [201]	train-mlogloss:0.405763	test-mlogloss:0.546063
# [202]	train-mlogloss:0.405245	test-mlogloss:0.546121
# [203]	train-mlogloss:0.404619	test-mlogloss:0.545943
# [204]	train-mlogloss:0.403901	test-mlogloss:0.545976
# [205]	train-mlogloss:0.403379	test-mlogloss:0.545912
# [206]	train-mlogloss:0.402793	test-mlogloss:0.545752
# [207]	train-mlogloss:0.402368	test-mlogloss:0.545601
# [208]	train-mlogloss:0.401667	test-mlogloss:0.5456
# [209]	train-mlogloss:0.401234	test-mlogloss:0.545522
# [210]	train-mlogloss:0.400489	test-mlogloss:0.545398
# [211]	train-mlogloss:0.399988	test-mlogloss:0.545406
# [212]	train-mlogloss:0.399393	test-mlogloss:0.545485
# [213]	train-mlogloss:0.399116	test-mlogloss:0.545495
# [214]	train-mlogloss:0.398275	test-mlogloss:0.545487
# [215]	train-mlogloss:0.398002	test-mlogloss:0.545557
# [216]	train-mlogloss:0.397505	test-mlogloss:0.545435
# [217]	train-mlogloss:0.396862	test-mlogloss:0.54547
# [218]	train-mlogloss:0.396258	test-mlogloss:0.545453
# [219]	train-mlogloss:0.395645	test-mlogloss:0.545399
# [220]	train-mlogloss:0.395305	test-mlogloss:0.545477
# [221]	train-mlogloss:0.394854	test-mlogloss:0.545422
# [222]	train-mlogloss:0.394612	test-mlogloss:0.545433
# [223]	train-mlogloss:0.394047	test-mlogloss:0.545398
# [224]	train-mlogloss:0.393563	test-mlogloss:0.545451
# [225]	train-mlogloss:0.392826	test-mlogloss:0.545543
# [226]	train-mlogloss:0.392338	test-mlogloss:0.545509
# [227]	train-mlogloss:0.391871	test-mlogloss:0.545423
# [228]	train-mlogloss:0.391467	test-mlogloss:0.545336
# [229]	train-mlogloss:0.391081	test-mlogloss:0.545295
# [230]	train-mlogloss:0.390629	test-mlogloss:0.545296
# [231]	train-mlogloss:0.390186	test-mlogloss:0.545495
# [232]	train-mlogloss:0.389636	test-mlogloss:0.545397
# [233]	train-mlogloss:0.389088	test-mlogloss:0.545351
# [234]	train-mlogloss:0.38869	test-mlogloss:0.545317
# [235]	train-mlogloss:0.388187	test-mlogloss:0.54537
# [236]	train-mlogloss:0.387678	test-mlogloss:0.545259
# [237]	train-mlogloss:0.387068	test-mlogloss:0.545311
# [238]	train-mlogloss:0.386611	test-mlogloss:0.545285
# [239]	train-mlogloss:0.386061	test-mlogloss:0.545184
# [240]	train-mlogloss:0.385581	test-mlogloss:0.545118
# [241]	train-mlogloss:0.38504	test-mlogloss:0.545195
# [242]	train-mlogloss:0.384531	test-mlogloss:0.545269
# [243]	train-mlogloss:0.384096	test-mlogloss:0.545275
# [244]	train-mlogloss:0.383611	test-mlogloss:0.545324
# [245]	train-mlogloss:0.38317	test-mlogloss:0.545415
# [246]	train-mlogloss:0.382715	test-mlogloss:0.545402
# [247]	train-mlogloss:0.382243	test-mlogloss:0.545507
# [248]	train-mlogloss:0.381788	test-mlogloss:0.545482
# [249]	train-mlogloss:0.38127	test-mlogloss:0.545474
# [250]	train-mlogloss:0.380679	test-mlogloss:0.54538
# [251]	train-mlogloss:0.380104	test-mlogloss:0.545307
# [252]	train-mlogloss:0.379633	test-mlogloss:0.545319
# [253]	train-mlogloss:0.379169	test-mlogloss:0.545304
# [254]	train-mlogloss:0.378793	test-mlogloss:0.545264
# [255]	train-mlogloss:0.378348	test-mlogloss:0.545405
# [256]	train-mlogloss:0.377878	test-mlogloss:0.545338
# [257]	train-mlogloss:0.377484	test-mlogloss:0.545385
# [258]	train-mlogloss:0.376991	test-mlogloss:0.545382
# [259]	train-mlogloss:0.376406	test-mlogloss:0.545394
# [260]	train-mlogloss:0.37592	test-mlogloss:0.545454
# Stopping. Best iteration:
# [240]	train-mlogloss:0.385581	test-mlogloss:0.545118
# [0.54545360062913861]

# %% [markdown]
# We will try to explore other variables that may be derived based on the cluster to which the rental unit belongs, such as the median price based on cluster id, number of bedrooms and number of bathrooms. Based on the results, we can see that introducing the variables, increases significantly the log loss. Therefore we will not include this variables in the final model.

# %%
train_X_full, test_X_full = cluster_latlon(30, train_df, test_df)

train_group_by = train_X_full[["cluster_30","bedrooms", "bathrooms", "price"]].groupby(["cluster_30","bedrooms","bathrooms"]).median()
train_group_by = train_group_by.add_suffix('_med').reset_index()

train_X_full = train_X_full.merge(train_group_by, left_on=["cluster_30","bedrooms", "bathrooms"], right_on=["cluster_30","bedrooms", "bathrooms"], how='outer')
test_X_full = test_X_full.merge(train_group_by, left_on=["cluster_30","bedrooms","bathrooms"], right_on=["cluster_30","bedrooms","bathrooms"], how='left')

train_X_full["price_comparison"] = train_X_full["price"] - train_X_full["price_med"]
test_X_full["price_comparison"] = test_X_full["price"] - test_X_full["price_med"]
#print(train_X_full.columns.values)

train_df["cluster_30"] = train_X_full["cluster_30"]
test_df["cluster_30"] = test_X_full["cluster_30"]

train_df["price_comparison"] = train_X_full["price_comparison"]
test_df["price_comparison"] = test_X_full["price_comparison"]

features_to_use.append("cluster_30")
features_to_use.append("price_comparison")

train_X_sel = train_X_full[features_to_use]
test_X_sel = test_X_full[features_to_use]

train_model(train_X_sel, train_df['interest_level'])
# Out:
# C:\Users\sevda\Anaconda3\lib\site-packages\ipykernel\__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\sevda\Anaconda3\lib\site-packages\ipykernel\__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# [0]	train-mlogloss:1.0488	test-mlogloss:1.0507
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:1.00775	test-mlogloss:1.01118
# [2]	train-mlogloss:0.972497	test-mlogloss:0.977582
# [3]	train-mlogloss:0.942228	test-mlogloss:0.948856
# [4]	train-mlogloss:0.916273	test-mlogloss:0.924317
# [5]	train-mlogloss:0.89393	test-mlogloss:0.903315
# [6]	train-mlogloss:0.874446	test-mlogloss:0.885194
# [7]	train-mlogloss:0.857381	test-mlogloss:0.869446
# [8]	train-mlogloss:0.842499	test-mlogloss:0.855892
# [9]	train-mlogloss:0.829522	test-mlogloss:0.844174
# [10]	train-mlogloss:0.818484	test-mlogloss:0.834302
# [11]	train-mlogloss:0.808505	test-mlogloss:0.82561
# [12]	train-mlogloss:0.79978	test-mlogloss:0.818086
# [13]	train-mlogloss:0.79232	test-mlogloss:0.811653
# [14]	train-mlogloss:0.785463	test-mlogloss:0.806044
# [15]	train-mlogloss:0.779089	test-mlogloss:0.800623
# [16]	train-mlogloss:0.773485	test-mlogloss:0.796095
# [17]	train-mlogloss:0.76816	test-mlogloss:0.79214
# [18]	train-mlogloss:0.76365	test-mlogloss:0.788725
# [19]	train-mlogloss:0.759507	test-mlogloss:0.785872
# [20]	train-mlogloss:0.756175	test-mlogloss:0.783491
# [21]	train-mlogloss:0.753269	test-mlogloss:0.781318
# [22]	train-mlogloss:0.750319	test-mlogloss:0.779494
# [23]	train-mlogloss:0.747565	test-mlogloss:0.77771
# [24]	train-mlogloss:0.745237	test-mlogloss:0.776478
# [25]	train-mlogloss:0.743069	test-mlogloss:0.77523
# [26]	train-mlogloss:0.740705	test-mlogloss:0.773978
# [27]	train-mlogloss:0.738804	test-mlogloss:0.772959
# [28]	train-mlogloss:0.73702	test-mlogloss:0.771973
# [29]	train-mlogloss:0.73524	test-mlogloss:0.771073
# [30]	train-mlogloss:0.733559	test-mlogloss:0.770317
# [31]	train-mlogloss:0.732133	test-mlogloss:0.769913
# [32]	train-mlogloss:0.730721	test-mlogloss:0.769426
# [33]	train-mlogloss:0.729647	test-mlogloss:0.769132
# [34]	train-mlogloss:0.728508	test-mlogloss:0.768789
# [35]	train-mlogloss:0.727116	test-mlogloss:0.768624
# [36]	train-mlogloss:0.725693	test-mlogloss:0.76818
# [37]	train-mlogloss:0.724511	test-mlogloss:0.767984
# [38]	train-mlogloss:0.723161	test-mlogloss:0.767897
# [39]	train-mlogloss:0.722162	test-mlogloss:0.767687
# [40]	train-mlogloss:0.721144	test-mlogloss:0.767578
# [41]	train-mlogloss:0.720108	test-mlogloss:0.767431
# [42]	train-mlogloss:0.71895	test-mlogloss:0.767171
# [43]	train-mlogloss:0.717889	test-mlogloss:0.767232
# [44]	train-mlogloss:0.717045	test-mlogloss:0.767226
# [45]	train-mlogloss:0.716172	test-mlogloss:0.76723
# [46]	train-mlogloss:0.71489	test-mlogloss:0.767071
# [47]	train-mlogloss:0.714139	test-mlogloss:0.766935
# [48]	train-mlogloss:0.713276	test-mlogloss:0.766832
# [49]	train-mlogloss:0.712437	test-mlogloss:0.766832
# [50]	train-mlogloss:0.711451	test-mlogloss:0.766726
# [51]	train-mlogloss:0.710416	test-mlogloss:0.766517
# [52]	train-mlogloss:0.709293	test-mlogloss:0.766579
# [53]	train-mlogloss:0.708413	test-mlogloss:0.766612
# [54]	train-mlogloss:0.707637	test-mlogloss:0.76664
# [55]	train-mlogloss:0.706759	test-mlogloss:0.766565
# [56]	train-mlogloss:0.705679	test-mlogloss:0.766468
# [57]	train-mlogloss:0.70491	test-mlogloss:0.76638
# [58]	train-mlogloss:0.704155	test-mlogloss:0.766312
# [59]	train-mlogloss:0.703431	test-mlogloss:0.766278
# [60]	train-mlogloss:0.702749	test-mlogloss:0.766327
# [61]	train-mlogloss:0.701946	test-mlogloss:0.766471
# [62]	train-mlogloss:0.701504	test-mlogloss:0.766535
# [63]	train-mlogloss:0.700504	test-mlogloss:0.766562
# [64]	train-mlogloss:0.69977	test-mlogloss:0.766567
# [65]	train-mlogloss:0.69887	test-mlogloss:0.766714
# [66]	train-mlogloss:0.698283	test-mlogloss:0.766777
# [67]	train-mlogloss:0.697565	test-mlogloss:0.766698
# [68]	train-mlogloss:0.696607	test-mlogloss:0.766754
# [69]	train-mlogloss:0.696077	test-mlogloss:0.76682
# [70]	train-mlogloss:0.695346	test-mlogloss:0.766909
# [71]	train-mlogloss:0.694636	test-mlogloss:0.766845
# [72]	train-mlogloss:0.693679	test-mlogloss:0.766841
# [73]	train-mlogloss:0.692901	test-mlogloss:0.766882
# [74]	train-mlogloss:0.69207	test-mlogloss:0.766861
# [75]	train-mlogloss:0.691515	test-mlogloss:0.766869
# [76]	train-mlogloss:0.690939	test-mlogloss:0.766891
# [77]	train-mlogloss:0.690206	test-mlogloss:0.76681
# [78]	train-mlogloss:0.689537	test-mlogloss:0.766815
# [79]	train-mlogloss:0.688749	test-mlogloss:0.766877
# Stopping. Best iteration:
# [59]	train-mlogloss:0.703431	test-mlogloss:0.766278
# [0.76687707300267205]

# %%
train_X_full, test_X_full = cluster_latlon(18, train_df, test_df)

print(train_X_full.columns.values)

features_to_use_upd = features_to_use
features_to_use_upd.append("cluster_18")
#
print(features_to_use)
#features_to_use_upd.remove("cluster_9")
train_X_sel = train_X_full[features_to_use_upd]
test_X_sel = test_X_full[features_to_use_upd]

print(train_X_sel.columns.values)

train_model(train_X_sel, train_df['interest_level'])

features_to_use_upd.remove("cluster_18")
# Out:
# C:\Users\sevda\Anaconda3\lib\site-packages\ipykernel\__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\sevda\Anaconda3\lib\site-packages\ipykernel\__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ['bathrooms' 'bedrooms' 'building_id' 'created' 'date' 'dayofyear'
#  'density' 'description' 'display_address' 'features' 'hour'
#  'interest_level' 'latitude' 'listing_difference' 'listing_id'
#  'listing_id_min' 'longitude' 'manager_id' 'manager_level_high'
#  'manager_level_low' 'manager_level_medium' 'manager_skill'
#  'num_description_words' 'num_features' 'num_photos' 'photos' 'pos' 'price'
#  'price_diff' 'price_median' 'price_t' 'room_sum' 'street_address'
#  'street_address_count' 'type_df' 'weekday' 'weekofyear' 'cluster_18']
# ['bathrooms', 'bedrooms', 'latitude', 'longitude', 'listing_difference', 'price', 'price_t', 'num_photos', 'num_features', 'num_description_words', 'listing_id', 'price_diff', 'dayofyear', 'weekofyear', 'weekday', 'hour', 'street_address_count', 'manager_level_low', 'manager_level_medium', 'manager_level_high', 'density', 'manager_skill', 'cluster_18']
# ['bathrooms' 'bedrooms' 'latitude' 'longitude' 'listing_difference' 'price'
#  'price_t' 'num_photos' 'num_features' 'num_description_words' 'listing_id'
#  'price_diff' 'dayofyear' 'weekofyear' 'weekday' 'hour'
#  'street_address_count' 'manager_level_low' 'manager_level_medium'
#  'manager_level_high' 'density' 'manager_skill' 'cluster_18']
# [0]	train-mlogloss:1.03128	test-mlogloss:1.03371
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:0.975195	test-mlogloss:0.979741
# [2]	train-mlogloss:0.92823	test-mlogloss:0.934635
# [3]	train-mlogloss:0.885755	test-mlogloss:0.893694
# [4]	train-mlogloss:0.849337	test-mlogloss:0.859187
# [5]	train-mlogloss:0.81728	test-mlogloss:0.828707
# [6]	train-mlogloss:0.789873	test-mlogloss:0.802387
# [7]	train-mlogloss:0.765772	test-mlogloss:0.779637
# [8]	train-mlogloss:0.743955	test-mlogloss:0.758996
# [9]	train-mlogloss:0.724961	test-mlogloss:0.741462
# [10]	train-mlogloss:0.708295	test-mlogloss:0.725679
# [11]	train-mlogloss:0.692676	test-mlogloss:0.711153
# [12]	train-mlogloss:0.6788	test-mlogloss:0.698149
# [13]	train-mlogloss:0.666365	test-mlogloss:0.686699
# [14]	train-mlogloss:0.654725	test-mlogloss:0.676144
# [15]	train-mlogloss:0.644988	test-mlogloss:0.66734
# [16]	train-mlogloss:0.635852	test-mlogloss:0.65924
# [17]	train-mlogloss:0.627712	test-mlogloss:0.65215
# [18]	train-mlogloss:0.620328	test-mlogloss:0.645651
# [19]	train-mlogloss:0.613217	test-mlogloss:0.639561
# [20]	train-mlogloss:0.606911	test-mlogloss:0.633999
# [21]	train-mlogloss:0.601367	test-mlogloss:0.629279
# [22]	train-mlogloss:0.595996	test-mlogloss:0.624787
# [23]	train-mlogloss:0.590698	test-mlogloss:0.620137
# [24]	train-mlogloss:0.585945	test-mlogloss:0.616051
# [25]	train-mlogloss:0.581815	test-mlogloss:0.612738
# [26]	train-mlogloss:0.577785	test-mlogloss:0.609585
# [27]	train-mlogloss:0.57406	test-mlogloss:0.606601
# [28]	train-mlogloss:0.57062	test-mlogloss:0.603815
# [29]	train-mlogloss:0.567577	test-mlogloss:0.6016
# [30]	train-mlogloss:0.564452	test-mlogloss:0.599182
# [31]	train-mlogloss:0.561193	test-mlogloss:0.596639
# [32]	train-mlogloss:0.558582	test-mlogloss:0.594453
# [33]	train-mlogloss:0.556162	test-mlogloss:0.592934
# [34]	train-mlogloss:0.553935	test-mlogloss:0.591219
# [35]	train-mlogloss:0.55133	test-mlogloss:0.589414
# [36]	train-mlogloss:0.54902	test-mlogloss:0.587857
# [37]	train-mlogloss:0.547349	test-mlogloss:0.586645
# [38]	train-mlogloss:0.545574	test-mlogloss:0.585526
# [39]	train-mlogloss:0.543518	test-mlogloss:0.584114
# [40]	train-mlogloss:0.541266	test-mlogloss:0.582527
# [41]	train-mlogloss:0.539583	test-mlogloss:0.581538
# [42]	train-mlogloss:0.537944	test-mlogloss:0.580417
# [43]	train-mlogloss:0.536355	test-mlogloss:0.579452
# [44]	train-mlogloss:0.534417	test-mlogloss:0.578159
# [45]	train-mlogloss:0.532808	test-mlogloss:0.577251
# [46]	train-mlogloss:0.531047	test-mlogloss:0.576358
# [47]	train-mlogloss:0.529553	test-mlogloss:0.575641
# [48]	train-mlogloss:0.528226	test-mlogloss:0.575012
# [49]	train-mlogloss:0.526863	test-mlogloss:0.574337
# [50]	train-mlogloss:0.525548	test-mlogloss:0.573575
# [51]	train-mlogloss:0.524096	test-mlogloss:0.572757
# [52]	train-mlogloss:0.522867	test-mlogloss:0.57222
# [53]	train-mlogloss:0.521341	test-mlogloss:0.571563
# [54]	train-mlogloss:0.519894	test-mlogloss:0.571011
# [55]	train-mlogloss:0.518352	test-mlogloss:0.570376
# [56]	train-mlogloss:0.517183	test-mlogloss:0.569792
# [57]	train-mlogloss:0.51562	test-mlogloss:0.569084
# [58]	train-mlogloss:0.514488	test-mlogloss:0.568628
# [59]	train-mlogloss:0.513452	test-mlogloss:0.568017
# [60]	train-mlogloss:0.512415	test-mlogloss:0.567654
# [61]	train-mlogloss:0.51122	test-mlogloss:0.56736
# [62]	train-mlogloss:0.50979	test-mlogloss:0.566561
# [63]	train-mlogloss:0.508581	test-mlogloss:0.565883
# [64]	train-mlogloss:0.507768	test-mlogloss:0.565696
# [65]	train-mlogloss:0.506196	test-mlogloss:0.564988
# [66]	train-mlogloss:0.505122	test-mlogloss:0.564835
# [67]	train-mlogloss:0.503834	test-mlogloss:0.56426
# [68]	train-mlogloss:0.502669	test-mlogloss:0.563705
# [69]	train-mlogloss:0.501872	test-mlogloss:0.563395
# [70]	train-mlogloss:0.500423	test-mlogloss:0.562742
# [71]	train-mlogloss:0.499357	test-mlogloss:0.562478
# [72]	train-mlogloss:0.498458	test-mlogloss:0.562199
# [73]	train-mlogloss:0.496951	test-mlogloss:0.561751
# [74]	train-mlogloss:0.496187	test-mlogloss:0.561412
# [75]	train-mlogloss:0.495202	test-mlogloss:0.561105
# [76]	train-mlogloss:0.49423	test-mlogloss:0.560781
# [77]	train-mlogloss:0.493011	test-mlogloss:0.560379
# [78]	train-mlogloss:0.49185	test-mlogloss:0.560121
# [79]	train-mlogloss:0.49123	test-mlogloss:0.560017
# [80]	train-mlogloss:0.490503	test-mlogloss:0.559715
# [81]	train-mlogloss:0.48948	test-mlogloss:0.55937
# [82]	train-mlogloss:0.488498	test-mlogloss:0.559141
# [83]	train-mlogloss:0.487256	test-mlogloss:0.558838
# [84]	train-mlogloss:0.486304	test-mlogloss:0.558395
# [85]	train-mlogloss:0.485643	test-mlogloss:0.558179
# [86]	train-mlogloss:0.484783	test-mlogloss:0.557937
# [87]	train-mlogloss:0.484036	test-mlogloss:0.55771
# [88]	train-mlogloss:0.482909	test-mlogloss:0.557508
# [89]	train-mlogloss:0.481987	test-mlogloss:0.557235
# [90]	train-mlogloss:0.480951	test-mlogloss:0.557054
# [91]	train-mlogloss:0.479877	test-mlogloss:0.556696
# [92]	train-mlogloss:0.478791	test-mlogloss:0.556595
# [93]	train-mlogloss:0.478128	test-mlogloss:0.556531
# [94]	train-mlogloss:0.477401	test-mlogloss:0.556362
# [95]	train-mlogloss:0.476525	test-mlogloss:0.556054
# [96]	train-mlogloss:0.475724	test-mlogloss:0.556011
# [97]	train-mlogloss:0.475034	test-mlogloss:0.555994
# [98]	train-mlogloss:0.473993	test-mlogloss:0.55575
# [99]	train-mlogloss:0.472917	test-mlogloss:0.555484
# [100]	train-mlogloss:0.472369	test-mlogloss:0.55538
# [101]	train-mlogloss:0.471568	test-mlogloss:0.555218
# [102]	train-mlogloss:0.470783	test-mlogloss:0.55508
# [103]	train-mlogloss:0.470018	test-mlogloss:0.554751
# [104]	train-mlogloss:0.469202	test-mlogloss:0.554635
# [105]	train-mlogloss:0.468527	test-mlogloss:0.554387
# [106]	train-mlogloss:0.467741	test-mlogloss:0.554228
# [107]	train-mlogloss:0.466777	test-mlogloss:0.553904
# [108]	train-mlogloss:0.465946	test-mlogloss:0.553818
# [109]	train-mlogloss:0.465	test-mlogloss:0.553488
# [110]	train-mlogloss:0.464351	test-mlogloss:0.553299
# [111]	train-mlogloss:0.463538	test-mlogloss:0.553057
# [112]	train-mlogloss:0.462855	test-mlogloss:0.552856
# [113]	train-mlogloss:0.462128	test-mlogloss:0.552613
# [114]	train-mlogloss:0.461581	test-mlogloss:0.552622
# [115]	train-mlogloss:0.460783	test-mlogloss:0.552532
# [116]	train-mlogloss:0.459896	test-mlogloss:0.552304
# [117]	train-mlogloss:0.45917	test-mlogloss:0.552209
# [118]	train-mlogloss:0.458445	test-mlogloss:0.552054
# [119]	train-mlogloss:0.457786	test-mlogloss:0.551834
# [120]	train-mlogloss:0.457081	test-mlogloss:0.551707
# [121]	train-mlogloss:0.456327	test-mlogloss:0.551545
# [122]	train-mlogloss:0.455625	test-mlogloss:0.55142
# [123]	train-mlogloss:0.454844	test-mlogloss:0.551344
# [124]	train-mlogloss:0.454389	test-mlogloss:0.551244
# [125]	train-mlogloss:0.453496	test-mlogloss:0.551012
# [126]	train-mlogloss:0.452632	test-mlogloss:0.550996
# [127]	train-mlogloss:0.452024	test-mlogloss:0.550826
# [128]	train-mlogloss:0.451211	test-mlogloss:0.550694
# [129]	train-mlogloss:0.450644	test-mlogloss:0.55065
# [130]	train-mlogloss:0.449944	test-mlogloss:0.550599
# [131]	train-mlogloss:0.44924	test-mlogloss:0.550475
# [132]	train-mlogloss:0.448546	test-mlogloss:0.550396
# [133]	train-mlogloss:0.447991	test-mlogloss:0.550247
# [134]	train-mlogloss:0.447215	test-mlogloss:0.549918
# [135]	train-mlogloss:0.446638	test-mlogloss:0.549878
# [136]	train-mlogloss:0.44588	test-mlogloss:0.549726
# [137]	train-mlogloss:0.445051	test-mlogloss:0.549539
# [138]	train-mlogloss:0.44452	test-mlogloss:0.549591
# [139]	train-mlogloss:0.443746	test-mlogloss:0.549435
# [140]	train-mlogloss:0.443198	test-mlogloss:0.549344
# [141]	train-mlogloss:0.442513	test-mlogloss:0.549304
# [142]	train-mlogloss:0.441683	test-mlogloss:0.54931
# [143]	train-mlogloss:0.441085	test-mlogloss:0.549272
# [144]	train-mlogloss:0.440342	test-mlogloss:0.549031
# [145]	train-mlogloss:0.439581	test-mlogloss:0.548843
# [146]	train-mlogloss:0.438963	test-mlogloss:0.548806
# [147]	train-mlogloss:0.438334	test-mlogloss:0.548615
# [148]	train-mlogloss:0.437391	test-mlogloss:0.548474
# [149]	train-mlogloss:0.436886	test-mlogloss:0.548437
# [150]	train-mlogloss:0.436272	test-mlogloss:0.548422
# [151]	train-mlogloss:0.435802	test-mlogloss:0.548318
# [152]	train-mlogloss:0.435128	test-mlogloss:0.548251
# [153]	train-mlogloss:0.434573	test-mlogloss:0.548246
# [154]	train-mlogloss:0.433911	test-mlogloss:0.548089
# [155]	train-mlogloss:0.433063	test-mlogloss:0.54806
# [156]	train-mlogloss:0.432409	test-mlogloss:0.54807
# [157]	train-mlogloss:0.431805	test-mlogloss:0.548003
# [158]	train-mlogloss:0.431335	test-mlogloss:0.547915
# [159]	train-mlogloss:0.430993	test-mlogloss:0.54787
# [160]	train-mlogloss:0.430372	test-mlogloss:0.547768
# [161]	train-mlogloss:0.429842	test-mlogloss:0.547875
# [162]	train-mlogloss:0.429159	test-mlogloss:0.547799
# [163]	train-mlogloss:0.428725	test-mlogloss:0.547776
# [164]	train-mlogloss:0.428012	test-mlogloss:0.547711
# [165]	train-mlogloss:0.427221	test-mlogloss:0.547621
# [166]	train-mlogloss:0.42663	test-mlogloss:0.547546
# [167]	train-mlogloss:0.42586	test-mlogloss:0.547368
# [168]	train-mlogloss:0.425138	test-mlogloss:0.547388
# [169]	train-mlogloss:0.424496	test-mlogloss:0.547513
# [170]	train-mlogloss:0.423963	test-mlogloss:0.547453
# [171]	train-mlogloss:0.42335	test-mlogloss:0.547381
# [172]	train-mlogloss:0.422903	test-mlogloss:0.547246
# [173]	train-mlogloss:0.422419	test-mlogloss:0.547274
# [174]	train-mlogloss:0.421824	test-mlogloss:0.547176
# [175]	train-mlogloss:0.421195	test-mlogloss:0.547074
# [176]	train-mlogloss:0.420649	test-mlogloss:0.547115
# [177]	train-mlogloss:0.4199	test-mlogloss:0.547076
# [178]	train-mlogloss:0.419105	test-mlogloss:0.547097
# [179]	train-mlogloss:0.418461	test-mlogloss:0.547047
# [180]	train-mlogloss:0.417883	test-mlogloss:0.546912
# [181]	train-mlogloss:0.417317	test-mlogloss:0.546856
# [182]	train-mlogloss:0.416566	test-mlogloss:0.546777
# [183]	train-mlogloss:0.416068	test-mlogloss:0.546711
# [184]	train-mlogloss:0.415433	test-mlogloss:0.546688
# [185]	train-mlogloss:0.414892	test-mlogloss:0.546626
# [186]	train-mlogloss:0.41435	test-mlogloss:0.54654
# [187]	train-mlogloss:0.4137	test-mlogloss:0.546485
# [188]	train-mlogloss:0.413189	test-mlogloss:0.546466
# [189]	train-mlogloss:0.412867	test-mlogloss:0.546559
# [190]	train-mlogloss:0.412211	test-mlogloss:0.546541
# [191]	train-mlogloss:0.411776	test-mlogloss:0.546517
# [192]	train-mlogloss:0.411207	test-mlogloss:0.54644
# [193]	train-mlogloss:0.410462	test-mlogloss:0.546659
# [194]	train-mlogloss:0.409771	test-mlogloss:0.546659
# [195]	train-mlogloss:0.409376	test-mlogloss:0.546644
# [196]	train-mlogloss:0.408718	test-mlogloss:0.546613
# [197]	train-mlogloss:0.408251	test-mlogloss:0.546488
# [198]	train-mlogloss:0.407512	test-mlogloss:0.546462
# [199]	train-mlogloss:0.407008	test-mlogloss:0.546448
# [200]	train-mlogloss:0.406394	test-mlogloss:0.546535
# [201]	train-mlogloss:0.405633	test-mlogloss:0.546538
# [202]	train-mlogloss:0.405112	test-mlogloss:0.546562
# [203]	train-mlogloss:0.404428	test-mlogloss:0.546451
# [204]	train-mlogloss:0.403804	test-mlogloss:0.546399
# [205]	train-mlogloss:0.403096	test-mlogloss:0.546275
# [206]	train-mlogloss:0.402472	test-mlogloss:0.546214
# [207]	train-mlogloss:0.402021	test-mlogloss:0.546135
# [208]	train-mlogloss:0.401254	test-mlogloss:0.546081
# [209]	train-mlogloss:0.400805	test-mlogloss:0.546036
# [210]	train-mlogloss:0.40024	test-mlogloss:0.546167
# [211]	train-mlogloss:0.39966	test-mlogloss:0.546043
# [212]	train-mlogloss:0.399029	test-mlogloss:0.546104
# [213]	train-mlogloss:0.398729	test-mlogloss:0.54615
# [214]	train-mlogloss:0.398028	test-mlogloss:0.546165
# [215]	train-mlogloss:0.39769	test-mlogloss:0.546213
# [216]	train-mlogloss:0.39712	test-mlogloss:0.546148
# [217]	train-mlogloss:0.396359	test-mlogloss:0.546112
# [218]	train-mlogloss:0.395699	test-mlogloss:0.546025
# [219]	train-mlogloss:0.394981	test-mlogloss:0.546054
# [220]	train-mlogloss:0.394676	test-mlogloss:0.546105
# [221]	train-mlogloss:0.394028	test-mlogloss:0.546188
# [222]	train-mlogloss:0.393832	test-mlogloss:0.546236
# [223]	train-mlogloss:0.393292	test-mlogloss:0.546225
# [224]	train-mlogloss:0.3927	test-mlogloss:0.546233
# [225]	train-mlogloss:0.392073	test-mlogloss:0.546224
# [226]	train-mlogloss:0.391648	test-mlogloss:0.546199
# [227]	train-mlogloss:0.391135	test-mlogloss:0.546131
# [228]	train-mlogloss:0.390707	test-mlogloss:0.546088
# [229]	train-mlogloss:0.39023	test-mlogloss:0.545986
# [230]	train-mlogloss:0.389761	test-mlogloss:0.545929
# [231]	train-mlogloss:0.389339	test-mlogloss:0.545924
# [232]	train-mlogloss:0.388673	test-mlogloss:0.545845
# [233]	train-mlogloss:0.388219	test-mlogloss:0.545806
# [234]	train-mlogloss:0.387697	test-mlogloss:0.545891
# [235]	train-mlogloss:0.387228	test-mlogloss:0.545832
# [236]	train-mlogloss:0.386756	test-mlogloss:0.545801
# [237]	train-mlogloss:0.386312	test-mlogloss:0.545746
# [238]	train-mlogloss:0.385786	test-mlogloss:0.545796
# [239]	train-mlogloss:0.385243	test-mlogloss:0.545765
# [240]	train-mlogloss:0.384825	test-mlogloss:0.54573
# [241]	train-mlogloss:0.384306	test-mlogloss:0.54578
# [242]	train-mlogloss:0.383851	test-mlogloss:0.545774
# [243]	train-mlogloss:0.383358	test-mlogloss:0.545855
# [244]	train-mlogloss:0.382922	test-mlogloss:0.545932
# [245]	train-mlogloss:0.382434	test-mlogloss:0.545906
# [246]	train-mlogloss:0.381928	test-mlogloss:0.545847
# [247]	train-mlogloss:0.381497	test-mlogloss:0.545867
# [248]	train-mlogloss:0.38107	test-mlogloss:0.545922
# [249]	train-mlogloss:0.380537	test-mlogloss:0.545859
# [250]	train-mlogloss:0.380126	test-mlogloss:0.545826
# [251]	train-mlogloss:0.379524	test-mlogloss:0.54578
# [252]	train-mlogloss:0.378893	test-mlogloss:0.545786
# [253]	train-mlogloss:0.378382	test-mlogloss:0.545613
# [254]	train-mlogloss:0.37796	test-mlogloss:0.545606
# [255]	train-mlogloss:0.377535	test-mlogloss:0.54577
# [256]	train-mlogloss:0.377032	test-mlogloss:0.545743
# [257]	train-mlogloss:0.376721	test-mlogloss:0.545715
# [258]	train-mlogloss:0.376164	test-mlogloss:0.545666
# [259]	train-mlogloss:0.375565	test-mlogloss:0.545626
# [260]	train-mlogloss:0.375037	test-mlogloss:0.545592
# [261]	train-mlogloss:0.374648	test-mlogloss:0.545589
# [262]	train-mlogloss:0.374122	test-mlogloss:0.545624
# [263]	train-mlogloss:0.373565	test-mlogloss:0.545574
# [264]	train-mlogloss:0.372927	test-mlogloss:0.545577
# [265]	train-mlogloss:0.372494	test-mlogloss:0.545603
# [266]	train-mlogloss:0.371881	test-mlogloss:0.545498
# [267]	train-mlogloss:0.371431	test-mlogloss:0.545456
# [268]	train-mlogloss:0.37104	test-mlogloss:0.54535
# [269]	train-mlogloss:0.370594	test-mlogloss:0.545362
# [270]	train-mlogloss:0.370061	test-mlogloss:0.545272
# [271]	train-mlogloss:0.369666	test-mlogloss:0.545343
# [272]	train-mlogloss:0.36926	test-mlogloss:0.545406
# [273]	train-mlogloss:0.368675	test-mlogloss:0.545372
# [274]	train-mlogloss:0.368268	test-mlogloss:0.545368
# [275]	train-mlogloss:0.367717	test-mlogloss:0.545254
# [276]	train-mlogloss:0.367246	test-mlogloss:0.545292
# [277]	train-mlogloss:0.366871	test-mlogloss:0.545256
# [278]	train-mlogloss:0.366423	test-mlogloss:0.545279
# [279]	train-mlogloss:0.365787	test-mlogloss:0.545194
# [280]	train-mlogloss:0.365251	test-mlogloss:0.545229
# [281]	train-mlogloss:0.364818	test-mlogloss:0.545241
# [282]	train-mlogloss:0.364209	test-mlogloss:0.54513
# [283]	train-mlogloss:0.363727	test-mlogloss:0.545018
# [284]	train-mlogloss:0.363406	test-mlogloss:0.545005
# [285]	train-mlogloss:0.362874	test-mlogloss:0.54506
# [286]	train-mlogloss:0.3623	test-mlogloss:0.545027
# [287]	train-mlogloss:0.361958	test-mlogloss:0.544999
# [288]	train-mlogloss:0.361467	test-mlogloss:0.544974
# [289]	train-mlogloss:0.36106	test-mlogloss:0.544978
# [290]	train-mlogloss:0.360617	test-mlogloss:0.544964
# [291]	train-mlogloss:0.360329	test-mlogloss:0.544942
# [292]	train-mlogloss:0.359789	test-mlogloss:0.544988
# [293]	train-mlogloss:0.359308	test-mlogloss:0.545114
# [294]	train-mlogloss:0.358939	test-mlogloss:0.545052
# [295]	train-mlogloss:0.358287	test-mlogloss:0.545043
# [296]	train-mlogloss:0.357806	test-mlogloss:0.545038
# [297]	train-mlogloss:0.357334	test-mlogloss:0.545031
# [298]	train-mlogloss:0.356792	test-mlogloss:0.545084
# [299]	train-mlogloss:0.356373	test-mlogloss:0.545036
# [300]	train-mlogloss:0.355963	test-mlogloss:0.544978
# [301]	train-mlogloss:0.355655	test-mlogloss:0.545008
# [302]	train-mlogloss:0.355316	test-mlogloss:0.545184
# [303]	train-mlogloss:0.354861	test-mlogloss:0.545204
# [304]	train-mlogloss:0.354513	test-mlogloss:0.545164
# [305]	train-mlogloss:0.353965	test-mlogloss:0.545202
# [306]	train-mlogloss:0.353412	test-mlogloss:0.545226
# [307]	train-mlogloss:0.353001	test-mlogloss:0.545287
# [308]	train-mlogloss:0.352562	test-mlogloss:0.545353
# [309]	train-mlogloss:0.352004	test-mlogloss:0.545431
# [310]	train-mlogloss:0.351631	test-mlogloss:0.545473
# [311]	train-mlogloss:0.351129	test-mlogloss:0.54547
# Stopping. Best iteration:
# [291]	train-mlogloss:0.360329	test-mlogloss:0.544942

# %% [markdown]
# Transforming the feature variable.

# %%
train_df['features'] = train_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
test_df['features'] = test_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
print(train_df["features"].head())
tfidf = CountVectorizer(stop_words='english', max_features=200)
tr_sparse = tfidf.fit_transform(train_df["features"])
te_sparse = tfidf.transform(test_df["features"])

col_desc = ['desc_'+ i for i in tfidf.get_feature_names()] 
count_vect_df = pd.DataFrame(tr_sparse.todense(), columns=col_desc)
train_X_full = pd.concat([train_df[features_to_use].reset_index(),count_vect_df],axis=1)

count_vect_test_df = pd.DataFrame(te_sparse.todense(), columns=col_desc)
test_X_full = pd.concat([test_df[features_to_use].reset_index(),count_vect_test_df],axis=1)
# Out:
# 0
# 1
# 2
# 3          Doorman Elevator Dishwasher Hardwood_Floors
# 4    Fireplace Dining_Room Balcony Doorman Elevator...
# Name: features, dtype: object

# %% [markdown]
# Source for part of the code https://www.kaggle.com/ug2409/two-sigma-connect-rental-listing-inquiries/using-description-as-the-only-feature-72-cv

# %% [markdown]
# Now we will combine the newly created feature variables, which represent whether a feature is present or not, with the initial data frame

# %%
#Maybe we do not need this part
#train_X = sparse.hstack([train_df[features_to_use], tr_sparse]).tocsr()
#test_X = sparse.hstack([test_df[features_to_use], te_sparse]).tocsr()

target_num_map = {'high':0, 'medium':1, 'low':2}
train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))
#print(train_X.shape, test_X.shape)

# %%
train_model(train_X_full, train_df['interest_level'])
# Out:
# [0]	train-mlogloss:1.03114	test-mlogloss:1.03275
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:0.973952	test-mlogloss:0.977125
# [2]	train-mlogloss:0.925449	test-mlogloss:0.930058
# [3]	train-mlogloss:0.883715	test-mlogloss:0.889784
# [4]	train-mlogloss:0.847077	test-mlogloss:0.854644
# [5]	train-mlogloss:0.815211	test-mlogloss:0.823948
# [6]	train-mlogloss:0.786819	test-mlogloss:0.797031
# [7]	train-mlogloss:0.762399	test-mlogloss:0.774059
# [8]	train-mlogloss:0.740443	test-mlogloss:0.753238
# [9]	train-mlogloss:0.720919	test-mlogloss:0.735109
# [10]	train-mlogloss:0.703587	test-mlogloss:0.718859
# [11]	train-mlogloss:0.688253	test-mlogloss:0.704752
# [12]	train-mlogloss:0.674073	test-mlogloss:0.691848
# [13]	train-mlogloss:0.661514	test-mlogloss:0.680627
# [14]	train-mlogloss:0.650098	test-mlogloss:0.670243
# [15]	train-mlogloss:0.639956	test-mlogloss:0.661063
# [16]	train-mlogloss:0.630587	test-mlogloss:0.653012
# [17]	train-mlogloss:0.621848	test-mlogloss:0.645412
# [18]	train-mlogloss:0.614224	test-mlogloss:0.638749
# [19]	train-mlogloss:0.60703	test-mlogloss:0.632427
# [20]	train-mlogloss:0.600607	test-mlogloss:0.626985
# [21]	train-mlogloss:0.594419	test-mlogloss:0.621756
# [22]	train-mlogloss:0.588901	test-mlogloss:0.617184
# [23]	train-mlogloss:0.584062	test-mlogloss:0.613254
# [24]	train-mlogloss:0.579277	test-mlogloss:0.609353
# [25]	train-mlogloss:0.574525	test-mlogloss:0.605643
# [26]	train-mlogloss:0.57041	test-mlogloss:0.602647
# [27]	train-mlogloss:0.56675	test-mlogloss:0.599804
# [28]	train-mlogloss:0.562912	test-mlogloss:0.596754
# [29]	train-mlogloss:0.55948	test-mlogloss:0.594158
# [30]	train-mlogloss:0.55639	test-mlogloss:0.591905
# [31]	train-mlogloss:0.553636	test-mlogloss:0.589761
# [32]	train-mlogloss:0.550776	test-mlogloss:0.58788
# [33]	train-mlogloss:0.547995	test-mlogloss:0.585836
# [34]	train-mlogloss:0.54534	test-mlogloss:0.583966
# [35]	train-mlogloss:0.542934	test-mlogloss:0.582481
# [36]	train-mlogloss:0.540659	test-mlogloss:0.580867
# [37]	train-mlogloss:0.538135	test-mlogloss:0.57925
# [38]	train-mlogloss:0.535798	test-mlogloss:0.577593
# [39]	train-mlogloss:0.533721	test-mlogloss:0.576311
# [40]	train-mlogloss:0.531898	test-mlogloss:0.575195
# [41]	train-mlogloss:0.5298	test-mlogloss:0.573892
# [42]	train-mlogloss:0.527752	test-mlogloss:0.572841
# [43]	train-mlogloss:0.526114	test-mlogloss:0.571901
# [44]	train-mlogloss:0.524487	test-mlogloss:0.571032
# [45]	train-mlogloss:0.522729	test-mlogloss:0.570088
# [46]	train-mlogloss:0.520971	test-mlogloss:0.569079
# [47]	train-mlogloss:0.519685	test-mlogloss:0.568513
# [48]	train-mlogloss:0.517764	test-mlogloss:0.567673
# [49]	train-mlogloss:0.516053	test-mlogloss:0.566761
# [50]	train-mlogloss:0.514734	test-mlogloss:0.566066
# [51]	train-mlogloss:0.51343	test-mlogloss:0.565321
# [52]	train-mlogloss:0.512149	test-mlogloss:0.564522
# [53]	train-mlogloss:0.511018	test-mlogloss:0.563924
# [54]	train-mlogloss:0.509735	test-mlogloss:0.563382
# [55]	train-mlogloss:0.508376	test-mlogloss:0.562639
# [56]	train-mlogloss:0.506875	test-mlogloss:0.56206
# [57]	train-mlogloss:0.505673	test-mlogloss:0.561451
# [58]	train-mlogloss:0.504547	test-mlogloss:0.560887
# [59]	train-mlogloss:0.503182	test-mlogloss:0.560304
# [60]	train-mlogloss:0.502082	test-mlogloss:0.559749
# [61]	train-mlogloss:0.500906	test-mlogloss:0.559246
# [62]	train-mlogloss:0.50004	test-mlogloss:0.55894
# [63]	train-mlogloss:0.498931	test-mlogloss:0.558469
# [64]	train-mlogloss:0.497271	test-mlogloss:0.557768
# [65]	train-mlogloss:0.496099	test-mlogloss:0.557532
# [66]	train-mlogloss:0.494801	test-mlogloss:0.557089
# [67]	train-mlogloss:0.493424	test-mlogloss:0.556606
# [68]	train-mlogloss:0.492322	test-mlogloss:0.556234
# [69]	train-mlogloss:0.491143	test-mlogloss:0.555871
# [70]	train-mlogloss:0.490109	test-mlogloss:0.555412
# [71]	train-mlogloss:0.489213	test-mlogloss:0.555082
# [72]	train-mlogloss:0.488174	test-mlogloss:0.554658
# [73]	train-mlogloss:0.487307	test-mlogloss:0.554419
# [74]	train-mlogloss:0.486369	test-mlogloss:0.553974
# [75]	train-mlogloss:0.485255	test-mlogloss:0.553684
# [76]	train-mlogloss:0.484226	test-mlogloss:0.553332
# [77]	train-mlogloss:0.483447	test-mlogloss:0.553059
# [78]	train-mlogloss:0.482655	test-mlogloss:0.552906
# [79]	train-mlogloss:0.481821	test-mlogloss:0.552678
# [80]	train-mlogloss:0.481039	test-mlogloss:0.552417
# [81]	train-mlogloss:0.480325	test-mlogloss:0.552217
# [82]	train-mlogloss:0.479507	test-mlogloss:0.552022
# [83]	train-mlogloss:0.478503	test-mlogloss:0.551665
# [84]	train-mlogloss:0.477361	test-mlogloss:0.551302
# [85]	train-mlogloss:0.476513	test-mlogloss:0.551059
# [86]	train-mlogloss:0.475908	test-mlogloss:0.550911
# [87]	train-mlogloss:0.475182	test-mlogloss:0.550651
# [88]	train-mlogloss:0.47426	test-mlogloss:0.550422
# [89]	train-mlogloss:0.473153	test-mlogloss:0.550296
# [90]	train-mlogloss:0.472284	test-mlogloss:0.550085
# [91]	train-mlogloss:0.471557	test-mlogloss:0.549897
# [92]	train-mlogloss:0.470458	test-mlogloss:0.549515
# [93]	train-mlogloss:0.469269	test-mlogloss:0.549153
# [94]	train-mlogloss:0.468567	test-mlogloss:0.548958
# [95]	train-mlogloss:0.467842	test-mlogloss:0.548941
# [96]	train-mlogloss:0.46738	test-mlogloss:0.548793
# [97]	train-mlogloss:0.466572	test-mlogloss:0.548735
# [98]	train-mlogloss:0.46586	test-mlogloss:0.548544
# [99]	train-mlogloss:0.465211	test-mlogloss:0.548299
# [100]	train-mlogloss:0.464481	test-mlogloss:0.548232
# [101]	train-mlogloss:0.463818	test-mlogloss:0.548168
# [102]	train-mlogloss:0.462989	test-mlogloss:0.547739
# [103]	train-mlogloss:0.461983	test-mlogloss:0.547505
# [104]	train-mlogloss:0.461231	test-mlogloss:0.547386
# [105]	train-mlogloss:0.460526	test-mlogloss:0.547276
# [106]	train-mlogloss:0.459547	test-mlogloss:0.547032
# [107]	train-mlogloss:0.458928	test-mlogloss:0.546904
# [108]	train-mlogloss:0.458033	test-mlogloss:0.546626
# [109]	train-mlogloss:0.457293	test-mlogloss:0.546459
# [110]	train-mlogloss:0.456776	test-mlogloss:0.54638
# [111]	train-mlogloss:0.455944	test-mlogloss:0.546172
# [112]	train-mlogloss:0.45545	test-mlogloss:0.546034
# [113]	train-mlogloss:0.454938	test-mlogloss:0.545922
# [114]	train-mlogloss:0.453988	test-mlogloss:0.545837
# [115]	train-mlogloss:0.452904	test-mlogloss:0.545617
# [116]	train-mlogloss:0.452218	test-mlogloss:0.545456
# [117]	train-mlogloss:0.451606	test-mlogloss:0.545256
# [118]	train-mlogloss:0.450472	test-mlogloss:0.544965
# [119]	train-mlogloss:0.449804	test-mlogloss:0.54485
# [120]	train-mlogloss:0.449373	test-mlogloss:0.544772
# [121]	train-mlogloss:0.448647	test-mlogloss:0.544712
# [122]	train-mlogloss:0.447866	test-mlogloss:0.544488
# [123]	train-mlogloss:0.446805	test-mlogloss:0.544338
# [124]	train-mlogloss:0.446025	test-mlogloss:0.544322
# [125]	train-mlogloss:0.445478	test-mlogloss:0.544228
# [126]	train-mlogloss:0.44491	test-mlogloss:0.544091
# [127]	train-mlogloss:0.444075	test-mlogloss:0.543926
# [128]	train-mlogloss:0.443189	test-mlogloss:0.543905
# [129]	train-mlogloss:0.442582	test-mlogloss:0.543816
# [130]	train-mlogloss:0.441895	test-mlogloss:0.543788
# [131]	train-mlogloss:0.441387	test-mlogloss:0.543768
# [132]	train-mlogloss:0.440688	test-mlogloss:0.543647
# [133]	train-mlogloss:0.439502	test-mlogloss:0.543359
# [134]	train-mlogloss:0.438911	test-mlogloss:0.543297
# [135]	train-mlogloss:0.438346	test-mlogloss:0.543296
# [136]	train-mlogloss:0.43795	test-mlogloss:0.543227
# [137]	train-mlogloss:0.437496	test-mlogloss:0.543048
# [138]	train-mlogloss:0.4366	test-mlogloss:0.542901
# [139]	train-mlogloss:0.435834	test-mlogloss:0.542713
# [140]	train-mlogloss:0.435118	test-mlogloss:0.542638
# [141]	train-mlogloss:0.434297	test-mlogloss:0.542559
# [142]	train-mlogloss:0.433595	test-mlogloss:0.54244
# [143]	train-mlogloss:0.432954	test-mlogloss:0.542368
# [144]	train-mlogloss:0.432238	test-mlogloss:0.542261
# [145]	train-mlogloss:0.431515	test-mlogloss:0.542078
# [146]	train-mlogloss:0.430845	test-mlogloss:0.542052
# [147]	train-mlogloss:0.430035	test-mlogloss:0.541966
# [148]	train-mlogloss:0.429355	test-mlogloss:0.541843
# [149]	train-mlogloss:0.428769	test-mlogloss:0.541912
# [150]	train-mlogloss:0.428232	test-mlogloss:0.541842
# [151]	train-mlogloss:0.427419	test-mlogloss:0.541724
# [152]	train-mlogloss:0.426841	test-mlogloss:0.541676
# [153]	train-mlogloss:0.426102	test-mlogloss:0.541556
# [154]	train-mlogloss:0.42559	test-mlogloss:0.541479
# [155]	train-mlogloss:0.424919	test-mlogloss:0.541481
# [156]	train-mlogloss:0.424198	test-mlogloss:0.541405
# [157]	train-mlogloss:0.423458	test-mlogloss:0.541184
# [158]	train-mlogloss:0.422726	test-mlogloss:0.540975
# [159]	train-mlogloss:0.422284	test-mlogloss:0.540929
# [160]	train-mlogloss:0.421542	test-mlogloss:0.540737
# [161]	train-mlogloss:0.420871	test-mlogloss:0.540673
# [162]	train-mlogloss:0.420144	test-mlogloss:0.540625
# [163]	train-mlogloss:0.41956	test-mlogloss:0.540474
# [164]	train-mlogloss:0.419063	test-mlogloss:0.540468
# [165]	train-mlogloss:0.418574	test-mlogloss:0.54052
# [166]	train-mlogloss:0.417942	test-mlogloss:0.540405
# [167]	train-mlogloss:0.417402	test-mlogloss:0.540413
# [168]	train-mlogloss:0.416889	test-mlogloss:0.540366
# [169]	train-mlogloss:0.416336	test-mlogloss:0.540294
# [170]	train-mlogloss:0.415757	test-mlogloss:0.540206
# [171]	train-mlogloss:0.415237	test-mlogloss:0.540189
# [172]	train-mlogloss:0.414677	test-mlogloss:0.540051
# [173]	train-mlogloss:0.414061	test-mlogloss:0.539957
# [174]	train-mlogloss:0.41362	test-mlogloss:0.539796
# [175]	train-mlogloss:0.412946	test-mlogloss:0.539617
# [176]	train-mlogloss:0.412512	test-mlogloss:0.53968
# [177]	train-mlogloss:0.411616	test-mlogloss:0.539547
# [178]	train-mlogloss:0.410915	test-mlogloss:0.539483
# [179]	train-mlogloss:0.410185	test-mlogloss:0.539283
# [180]	train-mlogloss:0.409637	test-mlogloss:0.539262
# [181]	train-mlogloss:0.40905	test-mlogloss:0.539134
# [182]	train-mlogloss:0.408321	test-mlogloss:0.539038
# [183]	train-mlogloss:0.407656	test-mlogloss:0.538917
# [184]	train-mlogloss:0.407139	test-mlogloss:0.538944
# [185]	train-mlogloss:0.406378	test-mlogloss:0.538757
# [186]	train-mlogloss:0.405804	test-mlogloss:0.53863
# [187]	train-mlogloss:0.4051	test-mlogloss:0.538613
# [188]	train-mlogloss:0.404372	test-mlogloss:0.538574
# [189]	train-mlogloss:0.403882	test-mlogloss:0.538494
# [190]	train-mlogloss:0.403403	test-mlogloss:0.538536
# [191]	train-mlogloss:0.402804	test-mlogloss:0.538535
# [192]	train-mlogloss:0.402183	test-mlogloss:0.538558
# [193]	train-mlogloss:0.401769	test-mlogloss:0.538532
# [194]	train-mlogloss:0.401168	test-mlogloss:0.538505
# [195]	train-mlogloss:0.400623	test-mlogloss:0.538462
# [196]	train-mlogloss:0.399841	test-mlogloss:0.538436
# [197]	train-mlogloss:0.399277	test-mlogloss:0.538505
# [198]	train-mlogloss:0.398612	test-mlogloss:0.538475
# [199]	train-mlogloss:0.39804	test-mlogloss:0.538488
# [200]	train-mlogloss:0.397502	test-mlogloss:0.538473
# [201]	train-mlogloss:0.396861	test-mlogloss:0.538372
# [202]	train-mlogloss:0.396236	test-mlogloss:0.538204
# [203]	train-mlogloss:0.395495	test-mlogloss:0.538238
# [204]	train-mlogloss:0.394733	test-mlogloss:0.53811
# [205]	train-mlogloss:0.394192	test-mlogloss:0.538103
# [206]	train-mlogloss:0.393697	test-mlogloss:0.538067
# [207]	train-mlogloss:0.392958	test-mlogloss:0.538058
# [208]	train-mlogloss:0.392538	test-mlogloss:0.537986
# [209]	train-mlogloss:0.392149	test-mlogloss:0.537961
# [210]	train-mlogloss:0.391551	test-mlogloss:0.53794
# [211]	train-mlogloss:0.391022	test-mlogloss:0.537982
# [212]	train-mlogloss:0.390762	test-mlogloss:0.538024
# [213]	train-mlogloss:0.390261	test-mlogloss:0.537986
# [214]	train-mlogloss:0.389624	test-mlogloss:0.538087
# [215]	train-mlogloss:0.389123	test-mlogloss:0.537971
# [216]	train-mlogloss:0.388584	test-mlogloss:0.537927
# [217]	train-mlogloss:0.388088	test-mlogloss:0.537807
# [218]	train-mlogloss:0.387563	test-mlogloss:0.53773
# [219]	train-mlogloss:0.386922	test-mlogloss:0.537766
# [220]	train-mlogloss:0.386356	test-mlogloss:0.537835
# [221]	train-mlogloss:0.385517	test-mlogloss:0.537755
# [222]	train-mlogloss:0.384998	test-mlogloss:0.537654
# [223]	train-mlogloss:0.384513	test-mlogloss:0.537593
# [224]	train-mlogloss:0.384155	test-mlogloss:0.537629
# [225]	train-mlogloss:0.383601	test-mlogloss:0.53769
# [226]	train-mlogloss:0.383065	test-mlogloss:0.537603
# [227]	train-mlogloss:0.382337	test-mlogloss:0.537587
# [228]	train-mlogloss:0.381499	test-mlogloss:0.537449
# [229]	train-mlogloss:0.38082	test-mlogloss:0.537359
# [230]	train-mlogloss:0.380112	test-mlogloss:0.537286
# [231]	train-mlogloss:0.379625	test-mlogloss:0.537253
# [232]	train-mlogloss:0.379141	test-mlogloss:0.537234
# [233]	train-mlogloss:0.378529	test-mlogloss:0.53711
# [234]	train-mlogloss:0.378136	test-mlogloss:0.537179
# [235]	train-mlogloss:0.377569	test-mlogloss:0.537118
# [236]	train-mlogloss:0.377182	test-mlogloss:0.537201
# [237]	train-mlogloss:0.376539	test-mlogloss:0.537296
# [238]	train-mlogloss:0.375955	test-mlogloss:0.537238
# [239]	train-mlogloss:0.375568	test-mlogloss:0.537215
# [240]	train-mlogloss:0.375127	test-mlogloss:0.537174
# [241]	train-mlogloss:0.374542	test-mlogloss:0.53716
# [242]	train-mlogloss:0.374062	test-mlogloss:0.537139
# [243]	train-mlogloss:0.373406	test-mlogloss:0.537192
# [244]	train-mlogloss:0.372906	test-mlogloss:0.537096
# [245]	train-mlogloss:0.372407	test-mlogloss:0.537167
# [246]	train-mlogloss:0.372042	test-mlogloss:0.537092
# [247]	train-mlogloss:0.371612	test-mlogloss:0.537177
# [248]	train-mlogloss:0.371092	test-mlogloss:0.537126
# [249]	train-mlogloss:0.370573	test-mlogloss:0.537164
# [250]	train-mlogloss:0.369929	test-mlogloss:0.536985
# [251]	train-mlogloss:0.36937	test-mlogloss:0.537003
# [252]	train-mlogloss:0.368993	test-mlogloss:0.536983
# [253]	train-mlogloss:0.36838	test-mlogloss:0.536965
# [254]	train-mlogloss:0.367899	test-mlogloss:0.53698
# [255]	train-mlogloss:0.367417	test-mlogloss:0.537025
# [256]	train-mlogloss:0.366982	test-mlogloss:0.536975
# [257]	train-mlogloss:0.36643	test-mlogloss:0.537017
# [258]	train-mlogloss:0.366055	test-mlogloss:0.537103
# [259]	train-mlogloss:0.365606	test-mlogloss:0.53699
# [260]	train-mlogloss:0.365218	test-mlogloss:0.536955
# [261]	train-mlogloss:0.364947	test-mlogloss:0.537037
# [262]	train-mlogloss:0.364337	test-mlogloss:0.537013
# [263]	train-mlogloss:0.363866	test-mlogloss:0.537163
# [264]	train-mlogloss:0.363484	test-mlogloss:0.537183
# [265]	train-mlogloss:0.362975	test-mlogloss:0.537178
# [266]	train-mlogloss:0.362541	test-mlogloss:0.537176
# [267]	train-mlogloss:0.362018	test-mlogloss:0.537099
# [268]	train-mlogloss:0.36159	test-mlogloss:0.537134
# [269]	train-mlogloss:0.361093	test-mlogloss:0.537116
# [270]	train-mlogloss:0.360514	test-mlogloss:0.537151
# [271]	train-mlogloss:0.359895	test-mlogloss:0.537238
# [272]	train-mlogloss:0.359363	test-mlogloss:0.537312
# [273]	train-mlogloss:0.358991	test-mlogloss:0.537265
# [274]	train-mlogloss:0.358514	test-mlogloss:0.537306
# [275]	train-mlogloss:0.358134	test-mlogloss:0.537404
# [276]	train-mlogloss:0.35758	test-mlogloss:0.53737
# [277]	train-mlogloss:0.357125	test-mlogloss:0.537329
# [278]	train-mlogloss:0.356736	test-mlogloss:0.537339
# [279]	train-mlogloss:0.356035	test-mlogloss:0.537384
# [280]	train-mlogloss:0.355746	test-mlogloss:0.537525
# Stopping. Best iteration:
# [260]	train-mlogloss:0.365218	test-mlogloss:0.536955
# [0.53752546488402597]

# %%
# not needed
train_X_full = train_X_full.drop("listing_id", axis=1)
test_X_full = test_X_full.drop("listing_id", axis=1)

# %%
#preds, model = runXGB(train_X, train_y, test_X, num_rounds=300)
preds, model = runXGB(train_X_full, train_y, test_X_full, num_rounds=280)

out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_starter_results_v12.csv", index=False)
# Out:
# Before train function

# %%
from matplotlib import pylab as plt
from xgboost import plot_tree

importance = model.get_fscore()
importance = sorted(importance.items(), key=operator.itemgetter(1))

df = pd.DataFrame(importance, columns=['feature', 'fscore'])
df['fscore'] = df['fscore'] / df['fscore'].sum()
df = df[df['fscore']>0.02]

plt.style.use('ggplot') 

plt.figure()
df.plot()
df.plot(kind='barh', x='feature', y='fscore', legend=False, figsize=(6, 10))
plt.title('XGBoost Feature Importance')
plt.xlabel('relative importance')
plt.show()

# %% [markdown]
# Transforming the initial variabels by using a factor analysis.

# %%
print(train_X_full.shape)
print(test_X_full.shape)
# Out:
# (49352, 224)
# (74659, 224)

# %%
#from sklearn.decomposition import FactorAnalysis
#iris = load_iris()
#X, y = train_X_full, train_y
#train_X_full.info()
#print(train_X_full.columns.values)

from sklearn import decomposition, preprocessing
#print(train_X_full.describe())
#print(test_X_full[features_to_use].describe())

train_X_full.fillna(0, inplace=True)
test_X_full.fillna(0, inplace=True)

#print(type(train_X_full))
#print(train_X_full.isinf().sum().sum())
print(test_X_full.isnull().sum().sum())

#for col_name in test_X_full.columns.values:
#    print(col_name)
#    print(test_X_full[col_name].isnull().sum().sum())

train_X_normal_df = preprocessing.scale(train_X_full) # Normalization
test_X_normal_df = preprocessing.scale(test_X_full) 

fa = decomposition.FactorAnalysis(n_components = 15)
train_X_factor_df = fa.fit_transform(train_X_normal_df)
test_X_factor_df = fa.transform(test_X_normal_df)

#print (train_X_factor_df.shape) # Factor loadings


#factor = FactorAnalysis(random_state=101).fit(train_X_full)
# Out:
# 0

# %% [markdown]
# We will transform the predicted variable.

# %%
target_num_map = {'high':0, 'medium':1, 'low':2}
train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

# %% [markdown]
# Now we will perform cross validation with the extracted factors in order to see how many number of rounds should the XGBoost algorithm perform.

# %%
train_model(train_X_full, train_df['interest_level'])
# Out:
# [0]	train-mlogloss:1.03114	test-mlogloss:1.03275
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:0.973961	test-mlogloss:0.977134
# [2]	train-mlogloss:0.925459	test-mlogloss:0.930068
# [3]	train-mlogloss:0.883724	test-mlogloss:0.889805
# [4]	train-mlogloss:0.847081	test-mlogloss:0.854666
# [5]	train-mlogloss:0.81524	test-mlogloss:0.823974
# [6]	train-mlogloss:0.786853	test-mlogloss:0.797083
# [7]	train-mlogloss:0.762439	test-mlogloss:0.774107
# [8]	train-mlogloss:0.740481	test-mlogloss:0.753325
# [9]	train-mlogloss:0.720949	test-mlogloss:0.735182
# [10]	train-mlogloss:0.703611	test-mlogloss:0.718912
# [11]	train-mlogloss:0.688282	test-mlogloss:0.704827
# [12]	train-mlogloss:0.674139	test-mlogloss:0.691993
# [13]	train-mlogloss:0.661569	test-mlogloss:0.680777
# [14]	train-mlogloss:0.650128	test-mlogloss:0.670425
# [15]	train-mlogloss:0.639979	test-mlogloss:0.661228
# [16]	train-mlogloss:0.630569	test-mlogloss:0.653039
# [17]	train-mlogloss:0.621947	test-mlogloss:0.645523
# [18]	train-mlogloss:0.614293	test-mlogloss:0.63887
# [19]	train-mlogloss:0.607095	test-mlogloss:0.63255
# [20]	train-mlogloss:0.600701	test-mlogloss:0.627156
# [21]	train-mlogloss:0.594445	test-mlogloss:0.621794
# [22]	train-mlogloss:0.589019	test-mlogloss:0.617197
# [23]	train-mlogloss:0.584206	test-mlogloss:0.613264
# [24]	train-mlogloss:0.579394	test-mlogloss:0.609313
# [25]	train-mlogloss:0.574628	test-mlogloss:0.605559
# [26]	train-mlogloss:0.570509	test-mlogloss:0.602533
# [27]	train-mlogloss:0.566862	test-mlogloss:0.599765
# [28]	train-mlogloss:0.563011	test-mlogloss:0.596801
# [29]	train-mlogloss:0.559686	test-mlogloss:0.594251
# [30]	train-mlogloss:0.556588	test-mlogloss:0.591928
# [31]	train-mlogloss:0.553756	test-mlogloss:0.589805
# [32]	train-mlogloss:0.550921	test-mlogloss:0.587923
# [33]	train-mlogloss:0.548172	test-mlogloss:0.585963
# [34]	train-mlogloss:0.545506	test-mlogloss:0.584077
# [35]	train-mlogloss:0.543114	test-mlogloss:0.582546
# [36]	train-mlogloss:0.540854	test-mlogloss:0.580974
# [37]	train-mlogloss:0.53848	test-mlogloss:0.579758
# [38]	train-mlogloss:0.53614	test-mlogloss:0.578193
# [39]	train-mlogloss:0.534092	test-mlogloss:0.577026
# [40]	train-mlogloss:0.53228	test-mlogloss:0.575885
# [41]	train-mlogloss:0.530318	test-mlogloss:0.574582
# [42]	train-mlogloss:0.528315	test-mlogloss:0.573499
# [43]	train-mlogloss:0.526687	test-mlogloss:0.572375
# [44]	train-mlogloss:0.52531	test-mlogloss:0.571655
# [45]	train-mlogloss:0.523441	test-mlogloss:0.570651
# [46]	train-mlogloss:0.521638	test-mlogloss:0.569838
# [47]	train-mlogloss:0.520352	test-mlogloss:0.569284
# [48]	train-mlogloss:0.518514	test-mlogloss:0.568437
# [49]	train-mlogloss:0.516908	test-mlogloss:0.567501
# [50]	train-mlogloss:0.515484	test-mlogloss:0.566764
# [51]	train-mlogloss:0.5141	test-mlogloss:0.565943
# [52]	train-mlogloss:0.512776	test-mlogloss:0.565162
# [53]	train-mlogloss:0.511621	test-mlogloss:0.564529
# [54]	train-mlogloss:0.510273	test-mlogloss:0.563929
# [55]	train-mlogloss:0.508934	test-mlogloss:0.563204
# [56]	train-mlogloss:0.507289	test-mlogloss:0.562445
# [57]	train-mlogloss:0.505909	test-mlogloss:0.561859
# [58]	train-mlogloss:0.504832	test-mlogloss:0.561406
# [59]	train-mlogloss:0.503463	test-mlogloss:0.560837
# [60]	train-mlogloss:0.502051	test-mlogloss:0.560265
# [61]	train-mlogloss:0.50096	test-mlogloss:0.559894
# [62]	train-mlogloss:0.500041	test-mlogloss:0.559641
# [63]	train-mlogloss:0.49873	test-mlogloss:0.559005
# [64]	train-mlogloss:0.497585	test-mlogloss:0.55837
# [65]	train-mlogloss:0.496395	test-mlogloss:0.558046
# [66]	train-mlogloss:0.495235	test-mlogloss:0.557651
# [67]	train-mlogloss:0.49399	test-mlogloss:0.557178
# [68]	train-mlogloss:0.492871	test-mlogloss:0.556821
# [69]	train-mlogloss:0.491622	test-mlogloss:0.556488
# [70]	train-mlogloss:0.490549	test-mlogloss:0.555905
# [71]	train-mlogloss:0.489625	test-mlogloss:0.555611
# [72]	train-mlogloss:0.488649	test-mlogloss:0.55521
# [73]	train-mlogloss:0.487795	test-mlogloss:0.555071
# [74]	train-mlogloss:0.486874	test-mlogloss:0.554671
# [75]	train-mlogloss:0.485915	test-mlogloss:0.554477
# [76]	train-mlogloss:0.484807	test-mlogloss:0.553988
# [77]	train-mlogloss:0.483855	test-mlogloss:0.553732
# [78]	train-mlogloss:0.48291	test-mlogloss:0.553501
# [79]	train-mlogloss:0.481983	test-mlogloss:0.553236
# [80]	train-mlogloss:0.481108	test-mlogloss:0.553052
# [81]	train-mlogloss:0.48019	test-mlogloss:0.552668
# [82]	train-mlogloss:0.479246	test-mlogloss:0.552427
# [83]	train-mlogloss:0.478028	test-mlogloss:0.552128
# [84]	train-mlogloss:0.476881	test-mlogloss:0.551836
# [85]	train-mlogloss:0.475904	test-mlogloss:0.551416
# [86]	train-mlogloss:0.475267	test-mlogloss:0.551231
# [87]	train-mlogloss:0.474569	test-mlogloss:0.550892
# [88]	train-mlogloss:0.473853	test-mlogloss:0.550754
# [89]	train-mlogloss:0.472859	test-mlogloss:0.550562
# [90]	train-mlogloss:0.471712	test-mlogloss:0.550202
# [91]	train-mlogloss:0.470912	test-mlogloss:0.549878
# [92]	train-mlogloss:0.470029	test-mlogloss:0.549602
# [93]	train-mlogloss:0.469091	test-mlogloss:0.549369
# [94]	train-mlogloss:0.46817	test-mlogloss:0.549145
# [95]	train-mlogloss:0.467449	test-mlogloss:0.549104
# [96]	train-mlogloss:0.466967	test-mlogloss:0.548884
# [97]	train-mlogloss:0.466316	test-mlogloss:0.548806
# [98]	train-mlogloss:0.465471	test-mlogloss:0.548525
# [99]	train-mlogloss:0.464726	test-mlogloss:0.548301
# [100]	train-mlogloss:0.463944	test-mlogloss:0.548203
# [101]	train-mlogloss:0.463264	test-mlogloss:0.548018
# [102]	train-mlogloss:0.462326	test-mlogloss:0.547666
# [103]	train-mlogloss:0.461239	test-mlogloss:0.547469
# [104]	train-mlogloss:0.460552	test-mlogloss:0.54728
# [105]	train-mlogloss:0.459736	test-mlogloss:0.54702
# [106]	train-mlogloss:0.458761	test-mlogloss:0.546738
# [107]	train-mlogloss:0.458212	test-mlogloss:0.546612
# [108]	train-mlogloss:0.457205	test-mlogloss:0.546381
# [109]	train-mlogloss:0.456454	test-mlogloss:0.546196
# [110]	train-mlogloss:0.455963	test-mlogloss:0.546039
# [111]	train-mlogloss:0.455143	test-mlogloss:0.54583
# [112]	train-mlogloss:0.454627	test-mlogloss:0.545637
# [113]	train-mlogloss:0.453848	test-mlogloss:0.545475
# [114]	train-mlogloss:0.452936	test-mlogloss:0.545435
# [115]	train-mlogloss:0.452038	test-mlogloss:0.545235
# [116]	train-mlogloss:0.451433	test-mlogloss:0.545078
# [117]	train-mlogloss:0.450718	test-mlogloss:0.544758
# [118]	train-mlogloss:0.449675	test-mlogloss:0.544566
# [119]	train-mlogloss:0.448924	test-mlogloss:0.544351
# [120]	train-mlogloss:0.448493	test-mlogloss:0.544303
# [121]	train-mlogloss:0.447813	test-mlogloss:0.544221
# [122]	train-mlogloss:0.44719	test-mlogloss:0.544116
# [123]	train-mlogloss:0.446153	test-mlogloss:0.543972
# [124]	train-mlogloss:0.445296	test-mlogloss:0.54388
# [125]	train-mlogloss:0.444818	test-mlogloss:0.543832
# [126]	train-mlogloss:0.444261	test-mlogloss:0.543741
# [127]	train-mlogloss:0.443566	test-mlogloss:0.543592
# [128]	train-mlogloss:0.442812	test-mlogloss:0.543564
# [129]	train-mlogloss:0.442206	test-mlogloss:0.543532
# [130]	train-mlogloss:0.441575	test-mlogloss:0.543472
# [131]	train-mlogloss:0.441032	test-mlogloss:0.54345
# [132]	train-mlogloss:0.440436	test-mlogloss:0.543364
# [133]	train-mlogloss:0.439651	test-mlogloss:0.543201
# [134]	train-mlogloss:0.439047	test-mlogloss:0.543136
# [135]	train-mlogloss:0.438414	test-mlogloss:0.543106
# [136]	train-mlogloss:0.438062	test-mlogloss:0.543059
# [137]	train-mlogloss:0.437643	test-mlogloss:0.542904
# [138]	train-mlogloss:0.437056	test-mlogloss:0.542845
# [139]	train-mlogloss:0.436563	test-mlogloss:0.542787
# [140]	train-mlogloss:0.435902	test-mlogloss:0.542578
# [141]	train-mlogloss:0.434818	test-mlogloss:0.542521
# [142]	train-mlogloss:0.434075	test-mlogloss:0.542305
# [143]	train-mlogloss:0.433661	test-mlogloss:0.542219
# [144]	train-mlogloss:0.432852	test-mlogloss:0.542058
# [145]	train-mlogloss:0.43196	test-mlogloss:0.541912
# [146]	train-mlogloss:0.431268	test-mlogloss:0.54189
# [147]	train-mlogloss:0.430528	test-mlogloss:0.541787
# [148]	train-mlogloss:0.429925	test-mlogloss:0.54168
# [149]	train-mlogloss:0.429377	test-mlogloss:0.541701
# [150]	train-mlogloss:0.428753	test-mlogloss:0.541764
# [151]	train-mlogloss:0.428008	test-mlogloss:0.541602
# [152]	train-mlogloss:0.427534	test-mlogloss:0.541524
# [153]	train-mlogloss:0.427045	test-mlogloss:0.541491
# [154]	train-mlogloss:0.426553	test-mlogloss:0.541463
# [155]	train-mlogloss:0.425982	test-mlogloss:0.54146
# [156]	train-mlogloss:0.425204	test-mlogloss:0.541323
# [157]	train-mlogloss:0.424706	test-mlogloss:0.541246
# [158]	train-mlogloss:0.424045	test-mlogloss:0.541116
# [159]	train-mlogloss:0.423676	test-mlogloss:0.541019
# [160]	train-mlogloss:0.422678	test-mlogloss:0.540849
# [161]	train-mlogloss:0.422081	test-mlogloss:0.540839
# [162]	train-mlogloss:0.421379	test-mlogloss:0.540825
# [163]	train-mlogloss:0.420831	test-mlogloss:0.540701
# [164]	train-mlogloss:0.420398	test-mlogloss:0.540683
# [165]	train-mlogloss:0.419885	test-mlogloss:0.540729
# [166]	train-mlogloss:0.419246	test-mlogloss:0.540587
# [167]	train-mlogloss:0.418715	test-mlogloss:0.5405
# [168]	train-mlogloss:0.4182	test-mlogloss:0.540312
# [169]	train-mlogloss:0.41762	test-mlogloss:0.540221
# [170]	train-mlogloss:0.417096	test-mlogloss:0.540083
# [171]	train-mlogloss:0.416499	test-mlogloss:0.540099
# [172]	train-mlogloss:0.415935	test-mlogloss:0.539848
# [173]	train-mlogloss:0.415316	test-mlogloss:0.539817
# [174]	train-mlogloss:0.414908	test-mlogloss:0.539685
# [175]	train-mlogloss:0.41418	test-mlogloss:0.539593
# [176]	train-mlogloss:0.413785	test-mlogloss:0.539486
# [177]	train-mlogloss:0.412886	test-mlogloss:0.539412
# [178]	train-mlogloss:0.412054	test-mlogloss:0.53948
# [179]	train-mlogloss:0.411356	test-mlogloss:0.539412
# [180]	train-mlogloss:0.410811	test-mlogloss:0.539367
# [181]	train-mlogloss:0.410368	test-mlogloss:0.539243
# [182]	train-mlogloss:0.409731	test-mlogloss:0.539219
# [183]	train-mlogloss:0.409195	test-mlogloss:0.539084
# [184]	train-mlogloss:0.408619	test-mlogloss:0.539134
# [185]	train-mlogloss:0.407812	test-mlogloss:0.538986
# [186]	train-mlogloss:0.407367	test-mlogloss:0.538948
# [187]	train-mlogloss:0.406645	test-mlogloss:0.538857
# [188]	train-mlogloss:0.405798	test-mlogloss:0.538809
# [189]	train-mlogloss:0.405343	test-mlogloss:0.538751
# [190]	train-mlogloss:0.404843	test-mlogloss:0.53876
# [191]	train-mlogloss:0.404175	test-mlogloss:0.538631
# [192]	train-mlogloss:0.403499	test-mlogloss:0.538608
# [193]	train-mlogloss:0.402917	test-mlogloss:0.538605
# [194]	train-mlogloss:0.402438	test-mlogloss:0.538477
# [195]	train-mlogloss:0.401736	test-mlogloss:0.538364
# [196]	train-mlogloss:0.401135	test-mlogloss:0.538404
# [197]	train-mlogloss:0.400461	test-mlogloss:0.538458
# [198]	train-mlogloss:0.39988	test-mlogloss:0.538337
# [199]	train-mlogloss:0.399295	test-mlogloss:0.538407
# [200]	train-mlogloss:0.398731	test-mlogloss:0.53837
# [201]	train-mlogloss:0.398095	test-mlogloss:0.538297
# [202]	train-mlogloss:0.39746	test-mlogloss:0.53821
# [203]	train-mlogloss:0.396808	test-mlogloss:0.538177
# [204]	train-mlogloss:0.396315	test-mlogloss:0.538018
# [205]	train-mlogloss:0.395732	test-mlogloss:0.537979
# [206]	train-mlogloss:0.395203	test-mlogloss:0.537872
# [207]	train-mlogloss:0.394476	test-mlogloss:0.537909
# [208]	train-mlogloss:0.394014	test-mlogloss:0.537889
# [209]	train-mlogloss:0.393611	test-mlogloss:0.537824
# [210]	train-mlogloss:0.393046	test-mlogloss:0.537832
# [211]	train-mlogloss:0.39244	test-mlogloss:0.537871
# [212]	train-mlogloss:0.392138	test-mlogloss:0.537893
# [213]	train-mlogloss:0.391656	test-mlogloss:0.537943
# [214]	train-mlogloss:0.391196	test-mlogloss:0.538023
# [215]	train-mlogloss:0.390669	test-mlogloss:0.537878
# [216]	train-mlogloss:0.390161	test-mlogloss:0.537905
# [217]	train-mlogloss:0.389719	test-mlogloss:0.537795
# [218]	train-mlogloss:0.389088	test-mlogloss:0.537691
# [219]	train-mlogloss:0.388506	test-mlogloss:0.537833
# [220]	train-mlogloss:0.387917	test-mlogloss:0.537767
# [221]	train-mlogloss:0.387042	test-mlogloss:0.537719
# [222]	train-mlogloss:0.386602	test-mlogloss:0.537716
# [223]	train-mlogloss:0.386141	test-mlogloss:0.537646
# [224]	train-mlogloss:0.385735	test-mlogloss:0.537742
# [225]	train-mlogloss:0.38519	test-mlogloss:0.537771
# [226]	train-mlogloss:0.384729	test-mlogloss:0.537853
# [227]	train-mlogloss:0.384094	test-mlogloss:0.537804
# [228]	train-mlogloss:0.383251	test-mlogloss:0.537629
# [229]	train-mlogloss:0.382631	test-mlogloss:0.537538
# [230]	train-mlogloss:0.382032	test-mlogloss:0.537553
# [231]	train-mlogloss:0.381687	test-mlogloss:0.537497
# [232]	train-mlogloss:0.381238	test-mlogloss:0.537461
# [233]	train-mlogloss:0.380573	test-mlogloss:0.537271
# [234]	train-mlogloss:0.380142	test-mlogloss:0.537298
# [235]	train-mlogloss:0.379537	test-mlogloss:0.537202
# [236]	train-mlogloss:0.379093	test-mlogloss:0.537197
# [237]	train-mlogloss:0.378438	test-mlogloss:0.537182
# [238]	train-mlogloss:0.377982	test-mlogloss:0.537158
# [239]	train-mlogloss:0.377565	test-mlogloss:0.537209
# [240]	train-mlogloss:0.377093	test-mlogloss:0.537289
# [241]	train-mlogloss:0.3765	test-mlogloss:0.537312
# [242]	train-mlogloss:0.375789	test-mlogloss:0.537289
# [243]	train-mlogloss:0.375204	test-mlogloss:0.53734
# [244]	train-mlogloss:0.374698	test-mlogloss:0.537288
# [245]	train-mlogloss:0.374291	test-mlogloss:0.53729
# [246]	train-mlogloss:0.374006	test-mlogloss:0.537267
# [247]	train-mlogloss:0.373673	test-mlogloss:0.537302
# [248]	train-mlogloss:0.373125	test-mlogloss:0.537244
# [249]	train-mlogloss:0.372674	test-mlogloss:0.537222
# [250]	train-mlogloss:0.372206	test-mlogloss:0.537095
# [251]	train-mlogloss:0.372004	test-mlogloss:0.537099
# [252]	train-mlogloss:0.371575	test-mlogloss:0.536986
# [253]	train-mlogloss:0.371045	test-mlogloss:0.536991
# [254]	train-mlogloss:0.37062	test-mlogloss:0.537057
# [255]	train-mlogloss:0.370046	test-mlogloss:0.53715
# [256]	train-mlogloss:0.369655	test-mlogloss:0.53709
# [257]	train-mlogloss:0.369066	test-mlogloss:0.537107
# [258]	train-mlogloss:0.368731	test-mlogloss:0.537171
# [259]	train-mlogloss:0.368158	test-mlogloss:0.537219
# [260]	train-mlogloss:0.367723	test-mlogloss:0.537177
# [261]	train-mlogloss:0.367375	test-mlogloss:0.53727
# [262]	train-mlogloss:0.366732	test-mlogloss:0.537296
# [263]	train-mlogloss:0.36624	test-mlogloss:0.537407
# [264]	train-mlogloss:0.365777	test-mlogloss:0.537434
# [265]	train-mlogloss:0.365225	test-mlogloss:0.537375
# [266]	train-mlogloss:0.364683	test-mlogloss:0.537367
# [267]	train-mlogloss:0.364232	test-mlogloss:0.537332
# [268]	train-mlogloss:0.363876	test-mlogloss:0.537346
# [269]	train-mlogloss:0.363355	test-mlogloss:0.537381
# [270]	train-mlogloss:0.362825	test-mlogloss:0.537374
# [271]	train-mlogloss:0.362069	test-mlogloss:0.537442
# [272]	train-mlogloss:0.361494	test-mlogloss:0.537491
# Stopping. Best iteration:
# [252]	train-mlogloss:0.371575	test-mlogloss:0.536986
# [0.53749112699032309]

# %% [markdown]
# After we've got the results from the cross validation, we will build the model on the train data set which is now transformed by the factors and then we will

# %%
#preds, model = runXGB(train_X, train_y, test_X, num_rounds=300)
preds, model = runXGB(train_X_factor_df, train_y, test_X_factor_df, num_rounds=280)

out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_starter_results_v16.csv", index=False)
# Out:
# Before train function

# %%
from matplotlib import pylab as plt
from xgboost import plot_tree

importance = model.get_fscore()
importance = sorted(importance.items(), key=operator.itemgetter(1))

df = pd.DataFrame(importance, columns=['feature', 'fscore'])
df['fscore'] = df['fscore'] / df['fscore'].sum()
df = df[df['fscore']>0.02]

plt.style.use('ggplot') 

plt.figure()
df.plot()
df.plot(kind='barh', x='feature', y='fscore', legend=False, figsize=(6, 10))
plt.title('XGBoost Feature Importance')
plt.xlabel('relative importance')
plt.show()

# %%
print(train_X_factor_df.shape)
print(fa.noise_variance_)
# Out:
# (49352, 20)
# [  8.72137262e-01   9.28055664e-01   9.65629135e-01   9.99506350e-01
#    9.99083264e-01   9.85330187e-01   1.40300766e-03   3.02805801e-02
#    9.43153973e-01   6.86768155e-03   7.90275369e-01   7.52756170e-02
#    2.59161514e-04   1.49161465e-03   3.21584297e-03   9.90583187e-01
#    9.18006324e-01   8.16829295e-01   4.60595874e-01   3.78023777e-01
#    4.36649596e-01   8.61704491e-01   2.01976245e-01   9.61878527e-01
#    9.42203833e-01   1.00000000e-12   9.99526686e-01   7.06146264e-01
#    9.99181745e-01   9.99580280e-01   9.99394851e-01   9.98944703e-01
#    9.99698558e-01   9.99446444e-01   9.99282041e-01   9.99423693e-01
#    9.99563242e-01   9.99444813e-01   9.98664172e-01   9.99218062e-01
#    9.99407289e-01   9.98664172e-01   8.40541818e-01   9.94752346e-01
#    1.00000000e-12   3.36686731e-01   9.61633146e-01   8.10149894e-01
#    8.13603854e-02   5.70732296e-01   9.73439589e-01   9.93723326e-01
#    9.80966783e-01   1.00000000e-12   8.01087928e-01   9.99732668e-01
#    8.40294429e-01   6.45486310e-01   8.01755436e-01   7.74900061e-01
#    3.61447854e-02   5.08814206e-01   1.00000000e-12   9.40430547e-01
#    9.14393740e-01   9.54353086e-01   5.65839426e-01   6.43824289e-01
#    7.97998463e-01   8.34972114e-01   5.23445117e-01   9.96643578e-01
#    8.44321340e-01   3.96855599e-02   9.92880633e-01   7.87914469e-01
#    5.84110636e-01   8.28207741e-01   5.49194749e-01   7.77269133e-01
#    1.00000000e-12   9.98295726e-01   9.72821665e-01   9.98930606e-01
#    9.18388610e-01   6.17643339e-01   9.02708012e-01   9.45716297e-01
#    9.89980873e-01   3.06101792e-01   5.40867318e-01   9.99705178e-01
#    1.00000000e-12   1.00000000e-12   9.94764075e-01   7.14099675e-01
#    3.62169055e-02   1.54268625e-01   9.73709434e-01   8.38921896e-02
#    9.99381426e-01   4.03699658e-01   9.99767781e-01   1.96085838e-02
#    6.68751727e-01   3.13173282e-01   4.86937516e-03   9.83602704e-01
#    9.57667278e-01   4.37323133e-01   6.95152281e-01   9.18809947e-01
#    9.89879563e-01   9.99388421e-01   9.99018407e-01   9.23305794e-01
#    7.05287451e-01   6.63564314e-01   7.41269865e-01   9.91369691e-01
#    5.40084937e-01   7.84272899e-01   7.99101605e-01   5.23167548e-01
#    9.72972527e-01   2.33592621e-01   8.24276578e-01   6.19933888e-01
#    9.99572934e-01   9.84189339e-01   5.87293112e-01   5.42412032e-01
#    1.34663307e-01   3.83218474e-01   4.02102779e-01   1.52642818e-01
#    9.97361207e-01   9.94006259e-01   9.78046220e-01   9.72972527e-01
#    8.23847033e-01   9.54617625e-01   6.93056050e-01   9.96847143e-01
#    7.52492595e-02   1.76534317e-01   1.91994490e-01   1.00000000e-12
#    9.38050881e-01   6.84335389e-01   8.83430329e-01   7.53292959e-01
#    9.55886486e-01   3.90017417e-02   2.35606743e-01   9.86759287e-01
#    8.60022314e-01   9.67572039e-01   3.53052096e-01   8.69397819e-01
#    8.70409728e-01   8.35773883e-02   9.66119519e-01   3.85798720e-01
#    7.77451300e-01   9.72643154e-01   8.97918600e-01   9.98779756e-01
#    9.90133403e-01   1.00000000e-12   8.60160980e-01   9.75667453e-01
#    8.67139519e-01   2.44315171e-01   6.92769618e-01   4.55442612e-01
#    1.93367904e-02   6.53491946e-01   9.51156070e-01   9.97414524e-01
#    3.69188060e-01   9.99302718e-01   2.52888383e-02   9.99621514e-01
#    9.94083021e-01   7.54727669e-01   9.70748094e-01   7.48840306e-01
#    9.99273442e-01   6.85409042e-03   2.70564356e-01   5.15538900e-01
#    4.51259609e-01   9.02874887e-01   5.27564529e-01   9.75602861e-01
#    1.64139940e-01   9.82673565e-01   4.45940559e-01   9.49144959e-01
#    4.78849924e-01   9.99282466e-01   2.53949738e-01   9.95939023e-01
#    8.56308935e-01   7.66971408e-01   1.00000000e-12   3.34640390e-01
#    1.55395387e-01   6.60683178e-01   7.01022190e-01   9.94258850e-01
#    9.84824814e-01   2.64737423e-01   9.92044424e-01   5.43624498e-01
#    9.66817732e-01   7.78868096e-01   6.91694835e-01   9.97930219e-01
#    8.83598292e-01   7.99781069e-01   5.29165918e-01   9.95407133e-01]

# %% [markdown]
# Predicting and saving the output.

# %%
print(train_X_full.columns.values)
# Out:
# ['index' 'bathrooms' 'bedrooms' 'latitude' 'longitude' 'listing_difference'
#  'price' 'price_t' 'num_photos' 'num_features' 'num_description_words'
#  'listing_id' 'price_diff' 'dayofyear' 'weekofyear' 'weekday' 'hour'
#  'street_address_count' 'manager_level_low' 'manager_level_medium'
#  'manager_level_high' 'density' 'manager_skill' 'cluster_30' 'desc_24'
#  'desc__balconies' 'desc__dishwasher_' 'desc__dryer' 'desc__eat'
#  'desc__elev' 'desc__exposed_brick_' 'desc__gourmet_kitchen_'
#  'desc__gut_renovated_' 'desc__lndry_bldg_' 'desc__massive_1br_home_'
#  'desc__mr_clean_approved_' 'desc__new_' 'desc__pets_ok_' 'desc__photos'
#  'desc__roomy_closets_' 'desc__walls_of_windows_' 'desc_actual_apt'
#  'desc_air_conditioning' 'desc_all_utilities_included' 'desc_assigned'
#  'desc_attended_lobby' 'desc_backyard' 'desc_balcony'
#  'desc_basement_storage' 'desc_bike_room' 'desc_bike_storage'
#  'desc_billiards_room' 'desc_brownstone' 'desc_building'
#  'desc_business_center' 'desc_cable' 'desc_cats_allowed' 'desc_central_a'
#  'desc_central_ac' 'desc_central_air' 'desc_children'
#  'desc_childrens_playroom' 'desc_common' 'desc_common_backyard'
#  'desc_common_garden' 'desc_common_outdoor_space' 'desc_common_parking'
#  'desc_common_roof_deck' 'desc_common_terrace'
#  'desc_community_recreation_facilities' 'desc_concierge'
#  'desc_concierge_service' 'desc_courtyard' 'desc_deck'
#  'desc_decorative_fireplace' 'desc_dining_room' 'desc_dishwasher'
#  'desc_dogs_allowed' 'desc_doorman' 'desc_dryer' 'desc_dryer_in_building'
#  'desc_dryer_in_unit' 'desc_duplex' 'desc_eat' 'desc_eat_in_kitchen'
#  'desc_elevator' 'desc_exclusive' 'desc_exposed_brick' 'desc_fireplace'
#  'desc_fitness' 'desc_fitness_center' 'desc_flex' 'desc_ft_doorman'
#  'desc_full_service_garage' 'desc_furnished' 'desc_garage' 'desc_garden'
#  'desc_granite_kitchen' 'desc_green_building' 'desc_guarantors_accepted'
#  'desc_gut_renovated' 'desc_gym' 'desc_gym_in_building' 'desc_hardwood'
#  'desc_hardwood_floors' 'desc_health_club' 'desc_hi_rise' 'desc_high'
#  'desc_high_ceiling' 'desc_high_ceilings' 'desc_high_speed_internet'
#  'desc_highrise' 'desc_in_closet' 'desc_in_kitchen' 'desc_in_kitchen_'
#  'desc_in_super' 'desc_in_superintendent' 'desc_indoor_pool' 'desc_laundry'
#  'desc_laundry_' 'desc_laundry_in_building' 'desc_laundry_in_unit'
#  'desc_laundry_on_floor' 'desc_laundry_room' 'desc_level' 'desc_light'
#  'desc_live' 'desc_live_in_super' 'desc_lndry_bldg_' 'desc_loft'
#  'desc_lounge' 'desc_lounge_room' 'desc_lowrise' 'desc_luxury_building'
#  'desc_mail_room' 'desc_marble_bath' 'desc_marble_bathroom'
#  'desc_microwave' 'desc_midrise' 'desc_multi' 'desc_new_construction'
#  'desc_newly_renovated' 'desc_no_fee' 'desc_no_pets' 'desc_nursery'
#  'desc_outdoor' 'desc_outdoor_areas' 'desc_outdoor_entertainment_space'
#  'desc_outdoor_pool' 'desc_outdoor_space' 'desc_package_room'
#  'desc_parking' 'desc_parking_space' 'desc_patio' 'desc_pet_friendly'
#  'desc_pets' 'desc_pets_allowed' 'desc_pets_on_approval' 'desc_playroom'
#  'desc_pool' 'desc_post' 'desc_post_war' 'desc_pre' 'desc_prewar'
#  'desc_private' 'desc_private_backyard' 'desc_private_balcony'
#  'desc_private_deck' 'desc_private_outdoor_space' 'desc_private_parking'
#  'desc_private_terrace' 'desc_publicoutdoor' 'desc_reduced_fee'
#  'desc_renovated' 'desc_residents_garden' 'desc_residents_lounge'
#  'desc_roof' 'desc_roof_deck' 'desc_roofdeck' 'desc_rooftop_deck'
#  'desc_rooftop_terrace' 'desc_s_kitchen_' 'desc_s_playroom'
#  'desc_satellite_tv' 'desc_sauna' 'desc_screening_room'
#  'desc_shared_backyard' 'desc_shares_ok' 'desc_short_term_allowed'
#  'desc_simplex' 'desc_site_garage' 'desc_site_laundry' 'desc_site_parking'
#  'desc_site_parking_lot' 'desc_site_super' 'desc_skylight' 'desc_space'
#  'desc_speed_internet' 'desc_stainless_steel_appliances' 'desc_storage'
#  'desc_storage_room' 'desc_sublet' 'desc_subway' 'desc_sundeck'
#  'desc_swimming_pool' 'desc_terrace' 'desc_terraces_' 'desc_time_doorman'
#  'desc_unit_washer' 'desc_valet' 'desc_valet_parking' 'desc_video_intercom'
#  'desc_view' 'desc_virtual_doorman' 'desc_walk' 'desc_walk_in_closet'
#  'desc_war' 'desc_washer' 'desc_washer_' 'desc_washer_in_unit'
#  'desc_wheelchair_access' 'desc_wheelchair_ramp' 'desc_wifi_access'
#  'desc_work']
